# %% [markdown]
# # Process for cleaning url lists from SQL database
#
# ## Step 0. Extract lists of urls for training sets from SQL database
#
# 1. The data is on pocitac database, so you can connect via MySQLWorkbench
# 1. Select the PVC database
# 1. There are 4 tables of interest, two with 'manual' in the name and two with 'approved'.  The manual are highest confidence, but we will use the approved ones because they include all the manual ones, and in the end, they are all suppressed.  This will give us a larger data set.  It is about 2.3 to 3k for the manual sets, but it is near 22 to 30k for the approved sets.
#
# ## These are the raw queries for the staffing and tech_consult lists
# ```SQL
# # These queries are repeated for staffing and tech_consult
# # select the pcv database!
#
# # good ones, around 3k
# select *
# from manual_suppress_on_url
# where reason='no_suppress'
#
# # 170810 udpated good ones, around 62k!
# select output_url
# from output
# group by output_url
# having min(primary_business_prod)=1
# limit 100000
# ;
#
# # staffing, around 22k
# select *
# from approved_suppress_on_url
# where reason='staffing'
# ;
#
# # tech_consult, around 30k
# select *
# from approved_suppress_on_url
# where reason='tech_consult'
# ;
# ```
#
# ## Export query results as csv, which will be in this format
# | id | url       | reason       | origin       | product_hits | added_at   |
# |----|-----------|--------------|--------------|--------------|------------|
# |  1 | acme.com  | tech_consult |  manual_jodi | 0            | 2016-09-09 |

# %% [markdown]
# ## 1 Extract single column url list from SQL output

# %%
"""
Extract data from csv files which are provided from the SQL database.

File Input format is described in last step
File Output format is a txt file with a single column one url per line


inputs:
    source_name, Filename/path of file containing raw url lists from database.
    output_name, Filename to use for file which will contain only the urls
return:
    None
"""
import re
import pandas as pd

filename = 'approved_suppress_staffing_170913.csv'
input_path = 'data/00_source_urls'
output_path = 'data/01_clean_url_lists'

source_name = "{}/{}".format(input_path, filename)
output_name = "{}/{}.txt".format(output_path, re.sub('\.\w*$', '',filename))



print "Reading input file and extracting the url vertical to save to file"
df = pd.read_csv(source_name)
df[['url']].to_csv(output_name, index=False) # index=False keeps it from writing out the row number...

print "Printing out the first rows of the output file for verification"
df_out = pd.read_csv(output_name)
df_out.head()

print "Saving result to ", output_name
print "ALL DONE"
df_out.head()
# Out:
# Reading input file and extracting the url vertical to save to file
# Printing out the first rows of the output file for verification
# Saving result to  data/01_clean_url_lists/approved_suppress_staffing_170913.txt
# ALL DONE
#               url
# 0     aghires.com
# 1  archirings.com
# 2       barona.fi
# 3  betterhire.com
# 4  bluecubeit.com

# %% [markdown]
# # 2 Download and save raw data html content for the url lists

# %%
# List available url lists for next step
# !ls data/01_clean_url_lists
# Out:
# 62k_new_good_ones.txt                 test.txt
# approved_suppress_staffing_170913.txt test_staff.txt

# %%
# Remove all known foreign language country url endings
def is_foreign_url_extension(url):
    foreign_extensions = [".mx", ".es", ".ar", ".cl", # spanish
                          ".se", # swedish
                          ".fr", ".tn", # french
                          ".dk", # danish
                          ".nl", ".be", # dutch
                          ".cz", # czech
                          ".it", # italian
                          ".br", ".pt", # portugese
                          ".de", ".ch", ".at", # german
                          ".no", # norwegian
                          ".pl", # polish
                          ".tr", # turkish
                          ]
    for ext in foreign_extensions:
        if url.endswith(ext):
            return True
    return False

source_file = 'data/170915_manual_tech_consult.csv'
target_file = 'data/170915_manual_tech_consult_noforext.csv'
with open(source_file, 'r') as source, open(target_file, 'w') as target:
    for line in source:
        url = line.strip()
        if not is_foreign_url_extension(url):
            target.write(url)
            target.write('\n')
            
print "DONE: Results written to ", target_file
# Out:
# DONE: Results written to  data/170915_manual_tech_consult_noforext.csv

# %%
# %%bash
# # if you see this message: dyld: Library not loaded: /usr/local/opt/readline/lib/libreadline.6.dylib
# # you need to upgrade bash via `brew upgrade bash`, then restart the kernel
#
# ## Run the output list from previous cell through the url-classifier in text saving mode.
# #. ../set_flag/return_full_text_on               # This sets an env variable which tells urlChecker to save content to disk
# export URL_FULL_CONTENT=True
#
# cat data/170915_manual_tech_consult_noforext.csv | \
#  python ../bin/urlChecker.py > \
#  data/170915_manual_tech_consult_noforext_content.tsv
# echo "DONE!"
# ### When the script finishes, you should have an html file in the `URL_SAVE_DEST` location named after the url, i.e. acme.com will have an acme.com file with the html content in it.
# Out:
# DONE!
# ----------
# volansys.com
# ciinc.com
# pyramidci.com
# bluecanopy.com
# asd-inc.com
# chreynolds.com
# blytheco.com
# azad.com
# banglalink.com.bd
# acis.co.in
# analytica.net
# cimarroninc.com
# asd-web.com
# adccinfocad.com
# apextgi.in
# cdac.in
# apertuspartners.com
# bylight.com
# auxilioinc.com
# andesaservices.com
# alchemists-ark.com
# cadgulf.com
# centerbeam.com
# cistel.com
# 4cplus.com
# capstonetek.com
# bridgeenergygroup.com
# arena-multimedia.com
# cat-amania.com
# brennanit.com.au
# asyst.co.id
# c7.com
# buzzclan.com
# circlesolutions.com
# calpinetech.com
# chipstechnologygroup.com
# ait.com
# c-cor.com.au
# betis.com
# b3solutions.com
# chrp-india.com
# atypon.com
# cogenteservices.com
# capitolofficesolutions.com
# axxumtech.com
# chinetworks.com
# bcfsolutions.com
# askusa.com
# it.arvato.com
# access-company.com
# deltek.com
# crmit.com
# aderant.com
# ibackup.com
# panaya.com
# trinet.com
# ntis.gov
# wbmd.com
# iskraemeco.com
# melissadata.com
# cts.wa.gov
# thinkvine.com
# delegosoftware.com
# loc8.com
# medevolve.com
# backblaze.com
# unanet.com
# vision6.com.au
# mycompas.com
# checkmarx.com
# infomedika.com
# intelliverse.com
# zemanta.com
# abtasty.com
# iqms.com
# websplanet.com
# redcondor.com
# ahrefs.com
# logicworks.net
# agilepoint.com
# rapid7.com
# talkwalker.com
# protiviti.com
# anzer.com
# africa.westcon.com
# cgi.com
# services.harman.com
# sourcehov.com
# sutherlandglobal.com
# accenture.com
# axelera.com.au
# " deliverycentric.com "
# " jds.net.au "
# " sccs.com.au "
# " softtestpays.com "
# " cygnuspro.com "
# " delegata.com "
# ngds.com
# " presidio.com "
# wfrtechnologies.com
# b-compservices.com
# captevo.com
# redsalsa.com
# advania.com
# camwood.com
# erpconnex.com
# erpst.com
# evry.com
# virtusapolaris.com
# williamswoodward.co.uk
# wsp-pb.com
# wyg.com
# bigbangerp.com
# cldpartners.com
# cleanslatetg.com
# ey.com
# lucrodyne.com
# nubik.ca
# scansource.com
# " scribesoft.com "
# 33floors.com
# aptsecure.com
# blisswebsolution.com
# envionsoftware.com
# technodrivesolutions.com
# iqzsystems.com
# retailwhizz.com
# maxsampartners.com
# stijc.com
# sensiple.com
# netrika.ru
# groupeafg.com
# candotechnologies.com
# softem.ro
# akshay.com
# siliconspec.com
# imaginary-spaces.com
# ghgsystems.com
# serenebyte.com
# datafoundry.com
# adgtech.net
# infence.com
# saisoftsol.com
# implementinformatics.com
# metaforic.com
# theborngroup.com
# orcapodservices.com
# wearetriple.com
# adayana.com
# knowarth.com
# genatec.com
# protegellc.com
# sparity.com
# emazzanti.net
# mzbusiness.com
# computerworldgroup.com
# isoftinnovations.com
# ceredox.com
# infocus-in.com
# sinergiatec.com
# nri.com
# datacomspecialists.com
# sarein.com
# netaccess-india.com
# advancedtech.com
# clustervision.com
# dtisystems.com
# saberpoint.com
# astra-north.com
# mccreade.com
# comarch.com
# datco.net
# actechnology.com
# apartechnologies.com
# brandonsystems.com
# breakaway-inc.com
# bytecubed.com
# cep-inc.com
# ceragence.com
# confideit.com
# convisoinc.com
# datasensesolutions.com
# deferonet.com
# elegantsolutions.us
# fipsar.com
# glgroup.site
# highernetworks.com
# indinus.com
# intellilinktech.com
# itsi-inc.com
# netsecurecorp.com
# oceanconsulting.com
# poasystems.com
# powernetamerica.com
# redrockbusiness.com
# sierravistagroup.com
# softintl.com
# taaratech.com
# thcllc.com
# yesdi.com
# ----------
# theprovatogroup.com
# apptadinc.com
# mindshift.com
# vicomnet.com
# ppc.com
# genious.com
# classicinformatics.com
# whishworks.com
# fusion-experience.com
# feeleurope.com
# deintec.com
# unitedglobalsoft.com
# netsolutionsindia.com
# exakis.com
# robosoftin.com
# adapt.com
# proximainformatica.com
# avisto.com
# 8kmiles.com
# nexage.com
# acquirebpo.com
# allgeier.com
# escatec.com
# grupoasd.com.co
# n3.nhs.uk
# telusinternational-europe.com
# combitech.com
# epicentertechnology.com
# fideltronik.com
# maclean.co.nz
# matrix-global.net
# oteplus.gr
# viettelidc.com.vn
# adaptra.com.au
# admiraltechnologies.in
# alten.com
# asseco.com
# avestacs.com
# browse2path.com
# cloudpipe.ca
# bi-basics.com
# cigniti.com
# csc.com
# datacloudsolutions.net
# f1soft.com
# gavstech.com
# globalsolutions.com.gh
# happiestminds.com
# hexaware.com
# idhasoft.com
# indigenasolutions.com
# indiumsoft.com
# itekna.com
# nidhusoft.com
# nttdata.com
# paragontech.net
# quartech.com
# returnonintelligence.com
# scalar.ca
# sogeti.com
# ssbs.com.sa
# technogeninc.com
# thakralone.com
# unicon-intl.com
# xby2.com
# cmc.net.pk
# curvature.com
# cxtec.com
# dayhuffgroup.com
# fusionstorm.com
# gsrti.com
# kyrasolutions.com
# mainland.ca
# palomasys.com
# riministreet.com
# samprasoft.com
# silverlinc.com
# spiderlogic.com
# symmetrycorp.com
# techstargroup.com
# itcorpz.com
# cwsc.com
# e-zencomp.com
# scc.com
# itcoalition.com
# ecsinc.com
# agilitynetworks.com
# cisus.com
# microage.com
# dls.net
# cambridgecomputer.com
# resourcecomputer.com
# atlanticdatasystems.com
# computer-plus.com
# itcadre.com
# itdirect.com
# clickcomputerservices.com
# inovas.net
# internalcomputerservices.com
# cover-all.ca
# itfreedom.com
# itkeysource.com
# crabtreecomputer.com
# metrocsg.com
# versatilecsi.com
# compugig.net
# one2oneinc.com
# starbase.co.uk
# rjmcomputerservices.com
# itideology.com
# gowyant.com
# avscomputer.com
# ccservices.com
# optimaservices.com
# prcomputer.net
# pcsknox.com
# itnexusinc.com
# mibar.net
# ccr1.com
# crowntechcomputer.com
# ctsinet.com
# mattnj.com
# sublimecomp.com
# apunix.com
# colemancomputers.com
# dmscomputerservices.com
# summitcomp.net
# itsource.com
# cleverducks.com
# crsc.ca
# crystalclearcomputersolutions.com
# renaissance.co.uk
# itinitiatives.com
# binec.com
# comprehensive.com
# hytekcomputers.com
# peoplescomputer.com
# saracomputers.com
# itechelon.com
# itstrategiesgroup.com
# allaroundcomputers.com
# scalearc.com
# coezion.com
# clts.com
# inp2s.com
# iqura.com
# compusoluciones.com
# matera.com
# tivit.com
# open-groupe.com
# softenger.com
# insags.com
# apside.com
# groupeastek.com
# itsgroup.com
# neurones.net
# groupe-logware.com
# nextret.net
# espire.com
# bechtle.com
# ozitem.com
# pramati.com
# proxiad.com
# ascenderstech.com
# trsb.net
# janyatech.com
# intrinsec.com
# linkbynet.com
# stonehouselogic.com
# satincorp.com
# inventechinfo.com
# icascorp.com
# shangotechnologies.com
# pantheonsolutionsinc.com
# databranch.com
# nacspl.com
# northeastsys.com
# otsi-usa.com
# techplussolutions.com
# itgfirm.com
# elabora.coop
# axa-groupsolutions.com
# leighton.com
# nwnit.com
# dynamicsq.com
# alacrityits.us
# myvbo.com
# itgenius.com
# ipitx.com
# avanteservices.com
# milessoft.com
# raremediacompany.in
# ideahelix.com
# verys.com
# interactivedigital.com
# harriague.com
# traficsurete.com
# kinetx.com
# bispl.com
# pinnaca.com
# ----------
# infocalix.com
# 3asoftinc.com
# makwiz.com
# cgen.com
# katalysttech.com
# ctogroup.com.au
# micropole.com
# 42milligrams.com
# mmit.com
# websupplements.in
# caxisweb.com
# algoritmusistemos.lt
# rkdsolutions.com
# zolipe.com
# ineteng.com
# convergeinfo.com
# productiveedge.com
# samsungsds.com
# megastar.in
# diversegov.com
# devoteam.co.uk
# devoteam.com
# netcompany.com
# " appirio.com "
# " dmsinc.com "
# " bitsltd.net "
# " frontier.in "
# " bluesoft.net.pl "
# " bluesoft.co.uk "
# " bluesoft-group.com "
# " true.nl "
# " isban.es "
# " isban.com "
# " isban.com.br "
# " barrister.com "
# " tecnocom.com.br "
# abs-inc.com
# mil.com
# atginc.com
# " tekcomms.com "
# " itcs-group.com "
# " claranet.com "
# claranet.co.uk
# " coreservices.com "
# " eesllc.net "
# " exis-ti.com "
# " oberon.eu "
# " pythian.com "
# " seltd.com "
# scsdynamics.com
# smg.com
# " business.com "
# " ctp.com "
# " bsscorp.com "
# icmltd.net
# icmcorporation.com
# bsigroup.com
# " lnttechnologyservices.com "
# " lttechnologyservices.com "
# " ctis.de "
# " ctis.com.mx "
# " ctisinc.com "
# " groupeonepoint.com "
# " techsolutions.net "
# " techsolutionsinc.com "
# " techsolutions.com "
# " techsolutionsllc.com "
# " synapse.com "
# " synapsellc.com "
# " man.com "
# " incedoinc.com "
# " computersolutions.ca "
# " computersolutions.ie "
# " futureplc.com "
# gft.com
# " caprusit.com "
# " dialog.com.au "
# " ains.com.au "
# ains.com
# " taldor.co.il "
# " link.pt "
# link.com
# " galaxe.com "
# " ntt.com "
# " innovainc.com "
# " telindus.nl "
# " interface.ru "
# axiom.co.za
# axiom-corp.com
# e-com-llc.com
# ibacompany.co.jp
# omnitechglobal.com
# it.ncs.net.in
# ncs-ltd.com
# " edgets.com "
# " itgct.com "
# " georgiait.com "
# thencsgroup.com
# aubay.com
# itconvergence.com
# attain.com
# intec.co.jp
# infomedia.co.id
# invoin.com
# quinnox.com
# horizon.ca
# isi-mtl.com
# flexity.com
# mis-inc.net
# umanis.com
# fulcrumco.com
# fulcrum-corp.com
# mnemo.com
# csltd.com.ua
# indigo-ltd.com
# micropole-institut.com
# eoh.com
# mts-usa.com
# innovasolutions.com
# " data3.com "
# " grupo-sms.com "
# gbm.net
# qualitestgroup.com
# iis.net
# linkconsulting.com
# highstreetit.com
# denovo-us.com
# caci.com
# prosoftgroup.com
# synechron.com
# asrcfederal.com
# aurionpro.com
# keywcorp.com
# merkleinc.com
# dexmedia.com
# groupe-sii.com
# bdo.com
# spirent.com
# macb.com
# mercer.com
# cmcltd.com
# getronics.com
# tatatechnologies.com
# capstonecorp.com
# melstar.com
# akka-technologies.com
# bytes.co.za
# sabresystems.com
# newhorizons.com
# crawfordandcompany.com
# lochbridge.com
# gpstrategies.com
# celad.com
# bull.com
# sqli.com
# mphasis.com
# logicalis.com
# datamatics.com
# issupppressstechnologies.com
# econocom.com
# ciber.com
# trigent.com
# sageoneinc.com
# aceinfosolutions.com
# ssupppressstematix.com
# pcm.com
# irissoftinc.com
# modulant.com
# cms.co.in
# cbsiglobal.com
# inautix.co.in
# compugen.com
# kandilit.com
# fxinnovation.com
# indecomm.net
# cavalieritinc.com
# buchanan.com
# powertekcorporation.com
# forartech.com
# promantisinc.com
# ssupppressnchronissupppresss.com
# criterion-ssupppresss.com
# cbts.cinbell.com
# constellationwest.com
# bluecanopsupppress.com
# inasolution.com
# teamcpn.com
# analsupppresstica.net
# marinc.com
# netenrich.com
# its.ws
# 9to9soft.com
# vertical1inc.com
# acrodex.com
# iopex.com
# techservicesllc.com
# nffinc.com
# mii.co.id
# incapsulate.com
# terpssupppresss.com
# ----------
# promenet.com
# mandrytechnology.com
# connectedtechnology.com
# everonit.com
# cygnus-sys.com
# trilogytechnologies.com
# karpel.com
# onlinecomputers.com
# datotel.com
# itnow.net
# activeco.com
# nspi.pcm.com
# corporatenetworkservices.com
# stammbt.com
# agile5technologies.com
# diversetechservices.com
# norhurst.com
# icomm.co.uk
# abbatech.com
# bvainc.com
# jbctraining.co.uk
# techcessgroup.com
# diversifiedcomputer.net
# truewater.com
# feddata.com
# halski.com
# vpsg.net
# swicktech.com
# lseven.com
# cns-service.com
# omnicomp.com
# 3tpro.com
# infoaxis.com
# goprodata.com
# gxanetworks.com
# ascentdata.com
# lanlogic.com
# pcmiracles.com
# dsatechnologies.com
# fullcsg.com
# responza.com
# f1computersolutions.com
# esitechadvisors.com
# polarsystems.com
# securebiznetworks.com
# netserve365.com
# vanndata.com
# isdesign.com
# tabinc.com
# allegianttechnology.com
# netwize.net
# agjsystems.com
# compufit.com
# zoginc.com
# baymcp.com
# netrixit.com
# ironedgegroup.com
# eguardtech.com
# altuscio.com
# bluelineservices.com
# encomputers.com
# generationix.com
# citoc.com
# infinitysts.com
# rcsprofessional.com
# rklcom.com
# gibraltarit.com
# networkelites.com
# slinternational.com
# iv4.com
# pacetechnical.com
# managedsystems.com
# infohedge.net
# simplex-it.com
# iovision.ca
# innovationnetworks.com
# infinitybusinessinc.com
# qeh2.com
# idigitalsystems.com
# purpleguys.com
# guidantpartners.com
# ciosolutions.com
# performanceit.com
# dngnet.com
# kobargo.com
# lansystem.com
# giaspace.com
# premiseinc.com
# computerdoctor.org
# databitinc.com
# pcsintl.com
# microvisionsinc.com
# georgejon.com
# netrepid.com
# streamlinenet.com
# pclantechs.com
# stabilitynetworks.com
# centuric.com
# peggnet.com
# myitpros.com
# clarecomputer.com
# another9.com
# platteriver.com
# thinktechonline.com
# mischoice.com
# windsweptit.com
# golime.co
# bypronto.com
# gradeatechs.com
# connectcomputer.com
# cornerstoneit.com
# corstar.com
# mytek.net
# netstrategy.net
# nstsystems.com
# myit.com
# 360itpartners.com
# xterrasolutions.com
# frameworkcommunications.com
# axiscomputernetworks.com
# reliancenet.com
# swifttechsolutions.com
# design-red.com
# global-usa.com
# tech-pointe.com
# lmstech.com
# flagshipnetworks.com
# aebackoffice.com
# soundshore.net
# nuagemanagedservices.com
# advanced-networks.com
# systemcareinc.com
# neocomp.com
# misalliance.com
# aleriotechgroup.com
# shipshapeit.com
# webpointitsolutions.com
# singernetworks.com
# aoknetworking.com
# illumen.com
# dtgi.net
# trgnetworking.com
# sorbis.com
# networkingresults.com
# fixedfeeit.com
# azbs.com
# itdata.com
# percentotech.com
# decisivebiz.com
# consulvation.com
# habergroup.com
# westechsolutions.com
# syndeotech.com
# ncs-grp.com
# atstechsolutions.com
# swiftecit.com
# digitalseattle.com
# shingdigital.com
# chelseacomputer.net
# syscomm.ca
# a3its.com
# unbreakableit.com
# unetek.com
# technologynow.com
# numanetworks.com
# entechus.com
# yumasolutions.com
# skyriverit.com
# midnightbluetech.com
# nexuspracticeit.com
# oztechs.com
# aertight.com
# dynamixsolutions.com
# leeshanok.com
# trustpointtech.com
# v2systems.com
# custech.net
# xaracomputers.co.uk
# epcits.com
# bridgehead-it.com
# sabioit.com
# enterprisehostinginc.com
# phreedom.com
# directitcorp.com
# ezissolutions.com
# bostonhelpdesk.com
# reis.ca
# alignedtechnologysolutions.com
# auxzillium.com
# thetechnologygroup.com
# netabn.com
# dataev.com
# nevtec.com
# technicalactiongroup.ca
# isworks.com
# thenetxperts.com
# ctcodeworks.com
# mx-tech.com
# syscon-inc.com
# svltechnologies.com
# ----------
# cloudrayinc.com
# ericrobert.com
# camdenvale.com
# thrivenetworks.com
# questsys.com
# cybsearch.com
# resultstechnology.com
# nitconnect.net
# latitudeinc.net
# iconx.com
# infostructures.com
# comtekglobal.com
# teramach.com
# veteransengineering.net
# gsquaredgroup.com
# ananke.com
# mytech.com
# sutoer.com
# medexpert.com
# ableforce.org
# dogwood.net
# tele-optics.com
# warnerconnect.com
# dynamiccampus.com
# bridgelinx.com
# datanetit.com
# switchfast.com
# kdi-inc.com
# greenfieldpartners.com
# neovera.com
# inhouseit.com
# flexstaf-it.ca
# rejis.org
# nextdimensioninc.com
# zeno-inc.com
# everynetwork.com
# accentvision.com
# jdltech.com
# stmicro.net
# safetynet-inc.com
# graffen.com
# sonanetworks.com
# kellerschroeder.com
# evros.ie
# careerkarmainc.com
# complete-it.co.uk
# geeksoncall.com
# ergos.com
# ironcitysearch.com
# aciinfotech.com
# centrics.com
# keylent.com
# netwoven.com
# thebulldogcompanies.com
# crescendollc.com
# itweapons.com
# technofinaservices.com
# ctiteksource.com
# ekmanassociates.com
# conceras.com
# thakral.com
# onshore.com
# pro4ia.com
# sumtio.com
# managedsolution.com
# lincolnit.com
# magnamious.net
# yjtsolutions.com
# precisionit.com
# transparenttech.com
# theautumngroupllc.com
# ctekcorp.com
# innovativecomp.com
# poweredbystl.com
# prescientsolutions.com
# predicainc.com
# masterinformatix.com
# clarisnetworks.com
# utgsolutions.com
# binatech.com
# bmtcorp.com
# mpcl.in
# zethos.com
# mstech.com
# accentonit.com
# graham-tech.net
# comp-hut.com
# biomedhsl.com
# tatecomputersystems.com
# 3points.com
# broadleafgroup.com
# smartsource-inc.com
# trivalentgroup.com
# zingersoftwaresolutions.com
# gennet.com
# kruberagroup.com
# pindisolutions.com
# quartetservice.com
# indigoit.com
# strategiccareers.com
# river-run.com
# alcortech.com
# kelsercorp.com
# softrams.com
# computernetworksinc.com
# externalit.com
# adaptivesolutions.com
# excaltech.com
# deerfoot.co.uk
# mis-solutions.com
# mapletronics.com
# micromenders.com
# capcomputer.com
# sennovate.com
# avonz.com
# dfwtechnology.com
# doxmsp.com
# thetnsgroup.com
# cisp.com
# xantrion.com
# insource.com
# wstusa.com
# softrim.com
# vpls.net
# edtsolutions.com
# e2services.net
# bbhsolutions.com
# syscomusa.com
# nuanza.com
# net56.com
# param-solutions.com
# versiant.com
# dynasis.com
# s3tech.ca
# throttlenet.com
# matscosolutions.com
# ioncomputer.com
# nucentric.com
# pltechnology.com
# electronicoffice.net
# hcmtek.com
# exigent.net
# panurgy.com
# integrityts.com
# tabush.com
# ngen.com
# proxios.com
# optimumnetworking.com
# zagtech.com
# idealintegrations.net
# joskos-solutions.com
# proserveit.com
# ancero.com
# easycomputing.com
# 4it-inc.com
# gradea.ca
# tucmanaged.com
# chelsea-tech.com
# rcg.com
# virtualtechnologiesgroup.com
# nextdigital.ca
# cogentassociates.com
# customis.com
# j4systems.com
# connectvip.ca
# infinetinc.com
# bansar.com
# master-it.com
# lexcom.ca
# uswired.com
# telagenllc.com
# varsitytechnologies.com
# tekmate.net
# broadviewnetworks.ca
# rocketit.com
# insol.org
# carolinasit.com
# lantium.com
# arabcomputers.com.sa
# computerguys.com
# rolandtechnology.com
# intelinetsystems.com
# rockit.com
# stringfellow.com
# stablenet.net
# cybertrails.com
# winningtech.com
# tech-keys.com
# jamesfrankassociates.com
# nettek.com
# acumenit.com
# troi.net
# singlepointoc.com
# acropolistech.com
# benchmarkpartnersllc.net
# wamsinc.com
# notonsite.com
# tsichicago.com
# cnp.net
# axxys.com
# ----------
# xrgsystems.com
# bluware.com
# dataprise.com
# arielpartners.com
# lloydit.com
# true-source.com
# vdx.com
# digitalprocedure.com
# lewisfowler.com
# nucleus10.com
# computerworkstech.com
# siriinfo.com
# oxyprime.com
# qstride.com
# gattoassociates.com
# infotreeservice.com
# globaltechservices.com
# tek-connexion.com
# humanlongevity.com
# woti.com
# skylinenet.net
# elevi.net
# inforeem.com
# compubahn.com
# infosysinternational.com
# devore.com
# apogeeitservices.com
# synoptek.com
# intellinet.com
# nexient.com
# bksinc.com
# logisofttechnologies.com
# qsolv-inc.com
# greenfieldpartnersinc.com
# comresource.com
# e-systemsgroup.com
# crystaldatasystems.net
# iventuresolutions.com
# hbs.net
# sigmanet.com
# computerworld.com
# astra-solutions.com
# nuevista.com
# siriusworks.com
# rkmcinc.com
# dextrys.com
# tech-niquepartners.com
# idasoft.com
# profconinc.com
# n2services.net
# correlationpoint.com
# omnilinkcorp.com
# providencepartners.com
# barebonesnetworking.com
# ntelicor.com
# easterndata.com
# fulcrumvets.com
# pelicantechnology.com
# neotechsolutions.com
# projectcc.com
# imethods.com
# lightedge.com
# knowledgematrixinc.com
# sqaconceptsinc.com
# icorps.com
# architechsolutions.com
# greenpages.com
# feisystems.com
# aquesst.com
# sourceselectgroup.com
# asquare.com
# intelecox.com
# gstiusa.com
# accentiqa.com
# oloop.net
# sreeinfotech.com
# ecalix.com
# itlab.com
# dtsi.com
# cognitim.com
# nutechs.com
# intigrow.com
# neelinfo.com
# rennerbrown.com
# entrecs.com
# softwarecatalysts.com
# hawkinspointpartners.com
# tomorrowsoffice.com
# bluewave-computing.com
# fwgsolutions.com
# graycon.com
# canbayinc.com
# talbridge.com
# ifinitesolutions.com
# techhive.com
# baanyan.com
# symquest.com
# fusionppt.com
# sritechsolutions.com
# teklinks.com
# enquero.com
# ivision.com
# gdrgroup.com
# pacificdataintegrators.com
# infinitecareersolutions.com
# masterpeaceltd.com
# aldridge.com
# bestitexperts.com
# connectingpeopleinc.com
# livevox.com
# ryleetechnologies.com
# dynasoftusa.com
# bravotech.com
# techoneit.rocks
# elementtechnologies.com
# kreeyaa.com
# magenium.com
# profile500.com
# synchronisys.com
# catapultservices.com
# corpinfo.com
# iventusit.com
# pyramidinc.com
# vigiboss.com
# shimento.com
# flexiblesystems.com
# primecaretech.com
# sureitinc.com
# lcginc.com
# hanselltierney.com
# smart-synergies.com
# luminoustec.com
# optimatechnologies.com
# advancementalternatives.com
# jessearch.com
# jamyinteractives.com
# teklead.com
# questeq.com
# venturesoft.com
# grapevinetechnology.com
# esense-inc.com
# aquratesolutions.com
# clearpointe.com
# accolite.com
# talgroup.net
# opteamix.com
# kenokozie.com
# vc3.com
# zot.com
# spikeitglobal.com
# pmgglobal.com
# safebridgeinc.com
# truetandem.com
# tusgi.com
# ctcg.co
# netstandard.com
# pronetcorp.com
# paranet.com
# ntiva.com
# marcumtechnology.com
# alphaserveit.com
# pcsolcorp.com
# heliontechnologies.com
# synergygs.com
# fentech.com
# provinet.com
# ucomusa.com
# diamondtechnologies.com
# devil-tech.com
# intervision.com
# sycomtech.com
# teneros.com
# zethostalentsolutions.com
# itavalon.com
# datalinedata.com
# bithgroup.com
# church-int.com
# edpsi.com
# amsysis.com
# cdillc.com
# xconic.com
# pghtech.org
# itauthorities.com
# theamegroup.com
# trilliumsg.com
# atrion.net
# newwave.io
# goshengroupllc.com
# precisiongroup.com
# htassociates.com
# cosolutions.com
# spotline.com
# mewa-llc.com
# datanetworks.com
# columbiaadvisory.com
# computertroubleshooters.co.uk
# britechgroup.com
# apgconsultants.com
# delphi-us.com
# coddingtongroup.com
# ----------
# ascentiant.com
# divihn.com
# cmpcorp.com
# lcgsystems.com
# intuites.com
# hmgamerica.com
# issginc.com
# urbanesystems.com
# primeteampartners.com
# rcgit.com
# sonsoftinc.com
# longview-inc.com
# greythorn.com
# bricklogix.com
# vibhainc.com
# precisiontechnologies.us
# ikasystems.com
# metabyte.com
# techead.com
# nousinfosystems.com
# amitechsolutions.com
# pksi.com
# softecinc.com
# criterion-sys.com
# fusionforte.com
# balancepointcorp.com
# nsight.com
# axiustek.com
# satechnologies.com
# plumchoice.com
# silversearchinc.com
# jrdsi.com
# growthsolutionsinc.com
# inirus.com
# technologynavigators.com
# vantagelinks.com
# datamanusa.com
# anexinet.com
# barkersearch.com
# verismsystems.com
# crgauction.com
# xinnovit.com
# walterandassociates.com
# kelway.com
# synergycom.com
# quardev.com
# infinitisystems.com
# gothamtg.com
# aebs.com
# dice.co.uk
# proactivestaff.com
# groupwaremax.com
# tsymmetry.com
# inergex.com
# dcshq.com
# techprimetime.com
# ferrerisearch.com
# arksolutionsinc.com
# infowarets.com
# compugrouptechnologies.com
# esp.com
# concept-inc.com
# stevendouglas.com
# smartlinkllc.com
# iquasar.com
# corsource.com
# tundratechnical.ca
# jeanmartin.com
# motusit.com
# albanosystems.com
# stlogics.com
# halogroup.us
# marathonts.com
# botsford-associates.com
# iiinfo.com
# ondemandgroup.com
# nscglobal.com
# datumsoftware.com
# onx.com
# corebts.com
# adaptivesg.com
# protechnicals.com
# alansgroup.com
# saratogasoftwaresolutions.com
# thenewberrygroup.com
# gst.com
# knowledgebuilders.com
# insigmaus.com
# pinpointrg.com
# venturesoftglobal.com
# partnertechnology.net
# terpsys.com
# dataexel.com
# tech-netinc.com
# clientsolv.com
# computerexpress.com
# cannonsp.com
# xtglobal.com
# halfaker.com
# bowmanwilliams.com
# kyyba.com
# triadgroup.com
# advansit.com
# psrassociates.com
# asisystem.com
# fastteks.com
# mmcsystems.com
# responsivesearch.com
# emergentsoftware.net
# infolob.com
# ics-nett.com
# rfa.com
# webcti.com
# galaxesystems.com
# smart-tek.net
# beaconsystems.com
# imatch.com
# tekstream.com
# beastute.com
# elitetechnical.com
# bicitisgroup.com
# zevatechnology.com
# tcognition.com
# gantech.net
# truestonefed.com
# placingit.com
# thevesumegroup.com
# aos5.com
# svsintegration.com
# cprime.com
# clerysys.com
# fyisolutions.com
# softnice.com
# hp.taleo.net
# rtgx.com
# premieralliance.net
# jvtadvisors.com
# valdezicorp.com
# innocoresolutions.com
# v-solve.com
# mwpartners.com
# enherent.com
# kore1.com
# signaturetechnology.com
# jraincengineers.com
# toplinestrategies.com
# atlantispartners.com
# netmatrixsolutions.com
# kovasys.com
# aimic.com
# delan.qc.ca
# isgtech.com
# inmata.com
# texcelvision.com
# wheelhouserp.com
# connvertex.com
# arrowcoregroup.com
# rwgamerica.com
# speridian.com
# zedventures.com
# trnsystems.com
# secure-24.com
# teamlogicit.com
# sixdimensions.com
# compasstechnologygroup.com
# gtcsystems.com
# herjavecgroup.com
# theoris.com
# f1techsolutions.com
# sedonatek.com
# firebrandtraining.co.uk
# govplace.com
# advantagetech.net
# utcassociates.com
# taskmanagement.com
# surrex.com
# sumeru.com
# projectleadership.net
# ameyaglobal.com
# relationalit.com
# sysazzle.com
# stiglobalservices.com
# futurewavesystems.com
# arthsystems.com
# processglobal.com
# btechinc.com
# nexerasolution.com
# sohosquaresolutions.com
# c2stechs.com
# thedenzelgroup.com
# cyquent.com
# federatedit.com
# evolutyz.com
# n-link.net
# fenwaygroup.com
# zentekinfosoft.com
# soroc.com
# xceleratesolutions.com
# sesolutions.com
# relianttech.com
# ----------
# requesttechnology.com
# systelinc.com
# synergis.com
# itscient.com
# comrise.com
# ises.com
# axistechnologiesinc.com
# shainassociates.com
# visionit.com
# makecor.com
# usmsystems.com
# akraya.com
# ashleyellis.com
# softworldinc.com
# hireitpeople.com
# objectwin.com
# vdartinc.com
# ntechsol.com
# itacsolutions.com
# ascent-corp.com
# thompsontalent.com
# systemtec.net
# tephrainc.com
# vortalsoft.com
# silverlinktechnologies.com
# itbrainiac.com
# damcosoft.com
# cnet-global.com
# genuent.net
# goaheadsolutions.com
# cybercoretech.com
# focuzmindz.com
# isystechnologies.com
# innovativesys.com
# harveynash.com
# aureusgroup.com
# vangent.com
# infoobjects.com
# microland.com
# soltech.net
# agreeya.com
# intelligent.net
# nextstepsystems.com
# prosol1.com
# optomi.com
# wpcg.ca
# cpsi.com
# datamasters.com
# redriversystems.com
# mindteck.com
# anteogroup.com
# hyattleader.com
# bridgeviewit.com
# i-cst.com
# inttechnologies.com
# saccinc.com
# winwire.com
# marsitcorp.com
# sra.com
# keystoneca.com
# thecentricsgroup.com
# timberhorn.com
# aesi.com
# prosum.com
# mmcgrp.com
# esi.net
# eappstech.com
# pyramidinc.org
# datainc.biz
# ctsit.com
# nutechsystems.com
# dynpro.com
# dpcit.com
# cesusa.com
# svam.com
# fusionsolutionsny.com
# rapisource.com
# howardsystems.com
# asen.com
# force3.com
# javentechnologies.com
# netcentrics.com
# omnione.com
# msrcosmos.com
# gdit.com
# blackdiamondnet.com
# evolverinc.com
# enterprisepals.com
# digicon.com
# datalinellc.com
# amzur.com
# fortek.com
# wimmersolutions.com
# unisonsystems.com
# beechwoodcomputing.com
# isltechsolutions.com
# yochanaitsolutions.com
# dewsoftware.com
# geocent.com
# agensys.com
# phoenixtp.com
# nuevainc.com
# conexess.com
# spi.com
# marvelinfotech.com
# pritechnology.com
# genuineitllc.com
# meridiangroup.com
# 3ktechnologies.com
# atrilogy.com
# sourcechip.net
# allcovered.com
# optimos.com
# aequor.com
# sentinel.com
# v2soft.com
# valcom.com
# digipulsetech.com
# trilogyts.com
# gssinfotech.com
# mcpc.com
# softcomsystems.com
# covestic.com
# designstrategy.com
# levanture.com
# hamilton-ryker.com
# psipax.com
# procom.ca
# sourceinfotech.com
# nesassociates.com
# mtm.com
# vbeyond.com
# iplaceusa.com
# force10networks.com
# earlywarning.com
# nexusis.com
# 3i-infotech.com
# peoplebank.com
# technocraftsolutions.in
# avitechnologies.net
# systemguru.com
# trustvip.com
# arescorporation.com
# bcssi.com
# csss.net
# rezultgroup.com
# technology-solution.com
# guntherdouglas.com
# redstreamtechnology.com
# fidelisprosolutions.com
# averypartners.com
# theroyakgroup.com
# zycron.com
# intermediagroup.org
# uniqsoftinc.com
# comtechglobal.com
# cssolutionsinc.com
# ncsus.net
# oneapps.com
# intelikore.com
# ssicom.com
# blueally.com
# cloverbusinesssolutions.com
# enpointe.com
# smartcaliber.com
# ptsystems.com
# bayonesolutions.com
# upp.com
# kanepartners.net
# arthurlawrence.net
# josephmichaels.com
# emeraldresourcegroup.com
# brycenetinc.com
# denaliai.com
# axiomtechgroup.com
# hollandsquare.com
# acumensolutions.com
# microexcel.com
# lucidtechnologies.net
# yasmesoft.com
# synigent.com
# altustek.com
# kanisolutions.com
# taluspartners.com
# systematix.com
# isgf.com
# prospanceinc.com
# realinterface.com
# oneneck.com
# tracesystems.com
# magna-systems.com
# epathusa.net
# taistech.com
# hexacorp.com
# resourcis.com
# oslosolutions.com
# solvingit.com
# cisinfo.net
# techcorps.org
# mamsys.com
# ----------
# wideservices.gr
# atomsystem.co.jp
# itiltd.co.uk
# elidoc.gr
# agilepeople.com.au
# domain.com.au
# esas.nu
# solita.fi
# neterra.tv
# adam.com.au
# lumis.ru
# omnicon.cc
# edita.com.eg
# qassociates.co.uk
# crosshead.co.jp
# softbox.co.uk
# resonatesolutions.com.au
# pro-bit.si
# rsn.com.co
# netvision.ba
# verio.eu
# unify.services
# tistech.co.ao
# flipit.lk
# jetcreative.co.uk
# medicalwebdesigns.co.uk
# onigroup.com.au
# web-merchant.co.uk
# webyte.co.uk
# corporates.review
# vivotelecommunications.co.uk
# inneo.co.uk
# zetta.com.au
# atentovenezuela.com.ve
# interoptics.gr
# itd.net.au
# ad2sell.in
# jbs.com.jo
# evolution-it.com.co
# linktechsolutions.com.au
# proactivepartners.us
# puck.eu
# cmps.in
# cjolivenetworks.co.kr
# dsm-design.co.uk
# webprofiters.ru
# brabbler.ag
# intellectit.com.au
# techbrain.com.au
# techbrain.co.in
# i3services.us
# ajsystems.co.uk
# queensland-seo.com.au
# crucial.com.au
# netcat.ru
# briston.com.au
# tm7.eu
# teamembedded.in
# cloudsolutionssa.co.za
# digitalsearchgroup.co.uk
# brm.ro
# brm.com.co
# izonesolutions.in
# certinergy.co.uk
# intelligentpathways.com.au
# paragon-creative.co.uk
# atsac.com.pe
# agava.ru
# terasys.com.co
# comability.com.au
# bang.com.au
# futurum.com.au
# peer.tv
# agilebi.com.au
# areait.info
# deltalogic.in
# vivogroup.com.au
# bangonline.com.au
# webtec.sk
# asic.co.za
# s2i-evolution.eu
# goshawkaerospace.co.uk
# uvt.ro
# systronic.com.au
# witz.com.au
# its.co.uk
# ans.co.uk
# boxfusion.co.za
# datak.ir
# mchost.ru
# zener.ae
# nua.ie
# firecrestcomputing.co.uk
# npf-marketing.co.uk
# visionet.co.id
# wgs.co.id
# esas.eu
# adv.ru
# mbdistributionltd.co.uk
# www.glgroup.site
# icservices.com.sg
# syntell.co.za
# spatialvision.com.au
# novastone.eu
# me.hk
# arkadin.com.sg
# msi-ecs.com.ph
# wisesystem.com.hk
# thefinalstep.co.uk
# thefinalstep.com.au
# redfoxmedia.com.au
# infosystems.info
# aprilis.com.hk
# linedmedia.com.au
# basis.org.bd
# nadra.gov.pk
# rysen.com.au
# beamap.co.uk
# canvasgroup.com.au
# theconfigteam.co.uk
# welkin.com.hk
# fusionapplications.com.au
# openmind.in
# macroview.com.au
# yourideas.org.uk
# knd.com.au
# writex.ru
# metapps.co.uk
# rileyandthomas.co.uk
# techcommerce.co.il
# san.com.pe
# clickthrough.co.nz
# ictteam.org.uk
# value.co.th
# alhoshan.com
# aptivacorp.com
# avnil.com
# axsiumgroup.com
# berghuishunt.com
# bhambi.com
# blackapple-solutions.com
# collaborative.com
# elixinc.com
# foiwe.com
# gestionempresaria.com
# globalminds.co.in
# gospyglass.com
# grcnordic.com
# guidacent.com
# hiberus.com
# iconbusinesssolutions.com
# itpeoplecorp.com
# kbscorp.com
# logicinfo.com
# lsc.co.uk
# manessens.com
# mindseeker.com
# nexusgroup.ca
# omnisolve.com
# p3synergy.com
# prglolinks.com
# promagsystems.com
# qintesi.com
# reqexperts.com
# rh-solutions.com
# s2itgroup.com
# sav-on-software.com
# schellden.com
# silasg.com
# siltek.com
# smartspoc.com
# softreachservices.com
# soft-strategy.com
# sparkpros.com
# synergicsolutionsinc.com
# tacook.com
# techcomsolutions.net
# techsoftsystems.com
# techspacesolutions.com
# tecnovaglobal.com
# thediligentgroup.com
# thenormangroup.com
# tribaltechllc.com
# tributetechno.com
# tytho.com
# universalbusinessteam.com
# voyagersolutions.com
# vui-inc.com
# westernacher.com
# wit-associes.com
# " atgcorp.com "
# isl.hk
# " pentalog.com "
# " pentalog.fr "
# wyle.com
# enterprisesolutioninc.com
# pomeroy.com
# disys.com
# synectics.com
# artechinfo.com
# ----------
# itsas.us
# theworkgroup.com.au
# itmsolutions.com.au
# abctechnology.co.uk
# codecdss.ie
# adservio.ro
# climber.eu
# netvalue.nz
# b4b.moscow
# digt.ru
# plan-netsa.com.au
# wynk.in
# variant.com.au
# designamite.co.za
# telekom.me
# rightsolution.co.uk
# qbit.co.za
# unity.ie
# mcscom.co.uk
# kcs.com.kw
# elcomplus.ru
# webmediagroup.com.au
# webmediagroup.ie
# everycity.co.uk
# carbonmedia.in
# medianova.co.ao
# adastra.sk
# datablue.gr
# millennium.ltd.uk
# softmark.in
# promsoft.ru
# ittrend.ru
# conceptmarketing.co.uk
# conceptmarketing.com.au
# perspektiv.co.uk
# brainsystems.com.pe
# brainsystems.ru
# globalweb.co.kr
# easycom.co
# netbooster.co.uk
# komtek.net.ua
# pacific.co.uk
# pacificcomputers.co.uk
# samsonsgroup.ae
# quantumweb.com.au
# itmagnet.com.au
# ingena.info
# netservicesrl.info
# apsit.org.in
# oratel.co.za
# coolvision.co.il
# coolvision.co.uk
# dpmtechnologies.in
# mango.com.bd
# preview.team
# iron-web.co.uk
# datatrade.com.hk
# synergistic.com.my
# megabits.co.za
# ihis.com.sg
# gen-c.co.uk
# web-planet.co
# netpointsolutions.co.uk
# netix.ru
# itpro.co.id
# emerging.com.au
# ubitech.in
# webdreams.in
# lotusagency.asia
# teewe.in
# lab.co.uk
# studioweb.co.id
# datasmith.com.au
# beyondedge.com.sg
# anzac.co.in
# livingdata.net.au
# evolvedesign.ie
# evolvedesign.co.uk
# dataprojekt.ee
# thedesignlab.us
# ttni.com.sg
# ttni.co.id
# csg.com.au
# csg-limited.co.uk
# mqa.org.za
# layer3.nz
# ultranet.com.eg
# ultranet.co.nz
# reverside.co.za
# infoconnect.com.my
# wafa.ae
# pro-scape.co.uk
# genexis.eu
# bigredgroup.co.uk
# teleweb.co.il
# codit.eu
# inovasi.us
# genex.co.in
# cardaccess.com.au
# asaco.in
# rootmedia.mobi
# contineo.sk
# thewebdoctor.firm.in
# bloomnet.eu
# divisadero.eu
# walkerscott.co
# workflowsolutions.co.uk
# dtdigital.co.uk
# dt.com.au
# isbel.com.uy
# teamsoft.com.pe
# americaxxi.com.ve
# ptml.co.nz
# lincom.net.au
# softsource.com.sg
# conio.com.au
# intelligentia.eu
# ipractice.in
# datalink.sa
# infoview.com.au
# mediahut.co.uk
# customercommunity.com.au
# nisz.hu
# webslice.eu
# factory.com.co
# deltacomputerservices.co.uk
# embedit.co.uk
# itelligence.ag
# inpas.ru
# transip.eu
# avantgardetechnologies.com.au
# enigen.co.uk
# manzanagroup.ru
# easypcltd.co.uk
# easypc.com.ph
# invisiblesolutions.co.za
# abs.com.my
# studionone.com.au
# ibacz.eu
# multimediax.com.au
# esrichina.com.cn
# pms.com.ve
# promatis.ru
# webservices4you.in
# crushed.co.uk
# madsolutions.com.au
# neurona.com.co
# xylos.ru
# nour.com.sa
# gammaservices.eu
# daronet.com.au
# secureservices.bh
# elucidate.co.nz
# first.eu
# ramtech.co.uk
# vsl.sk
# reachdata.co.uk
# eigen.in
# netway.eu
# legos.ru
# grasys.ru
# tesys.info
# taix.ru
# ctrlit.com.au
# decisions.co.uk
# brunelit.co.uk
# suncellular.com.ph
# opentec.com.au
# evagroup.com.au
# land.nrw
# inform-mobil.ru
# telkomsigma.co.id
# sndi.ci
# argaze.ma
# vitalify.asia
# graphicsunlimited.com.au
# e-sign.co.uk
# usetech.ru
# itsolvz.mu
# nps.rs
# layoutweb.co.uk
# thecreativeteam.co.uk
# permeance.com.au
# stadlerpartners.ro
# directcomputers.co.uk
# creacom.com.au
# esparsh.in
# gilon.co.il
# theassembly.co.za
# ok.is
# t-media.tv
# t-media.org.uk
# touchtech.co.nz
# cis-solutions.eu
# evolution7.com.au
# init.com.sg
# inisoft.co.uk
# dnvgl.co.uk
# getlogic.in
# tci-sa.co.za
# ----------
# businessoxygen.com.au
# cactus.net.nz
# newenergy.info
# newenergy.org.cn
# flexis.ru
# sintec.ru
# sit.com.sa
# r-tech.co.in
# trinexus.co
# digitalbridge.com.au
# telarus.com.au
# hrboss.co.jp
# post.lu
# exus.co.uk
# quarta.ru
# medisoft.co.uk
# everett.eu
# vizadanetworks.co.tz
# logicom.com.au
# prosis.com.uy
# icc.com.lb
# promarketing.ma
# thedesignpeople.ph
# thedesignpeople.in
# artmaster.com.au
# estilos.com.pe
# itservices.usc.edu
# equation.org.uk
# equation.co.za
# truedigital.co.uk
# dancom.com.my
# dedalus.eu
# citia.co.uk
# isolve.com.sg
# abcom.co.uk
# connectit.com.au
# connectit.co.uk
# software-dynamics.co.uk
# m2technology.com.au
# d-studio.fi
# edesign.co.in
# info-lan.ru
# lastexit.tv
# chillizone.com.au
# metco.co.in
# metcoinc.us
# novactive.us
# s5systems.us
# donuts.domains
# estore.com.au
# estore.co.id
# cemaltd.co.uk
# immagini.site
# m-wise.eu
# netra.io
# sparkdigital.co.nz
# ariadna.us
# interware.hu
# csbi.ru
# processflows.co.uk
# segi.edu.my
# stonegroup.co.uk
# sistec.ac.in
# inergo.gr
# bug-tracker.cn
# elogics.co.za
# cre8.com.au
# digitalzone.co.kr
# absolutecs.co.za
# mastercom.co.in
# medialounge.in
# t-services.ru
# qnh.eu
# itcentar.rs
# buscon.ru
# ictservices.ie
# reliableservices.net.in
# futureit.net.au
# graphit.hu
# stt.fi
# huddlegroup.com.au
# lemberg.co.uk
# meinhardt.com.au
# bluedigital.co.uk
# bluedigital.co.in
# hotelmanagementsystem.co.in
# infomedia-services.co.uk
# infomedia.com.sg
# m-2.ru
# quantium.com.au
# appsource.in
# appsource.co.in
# enterpriseit.co.nz
# ikan.com.pk
# splashinteractive.com.cn
# splashinteractive.com.sg
# logrus.ru
# travelsoft.co.za
# edpnet.ru
# infocenter.com.py
# infocenter.com.kw
# itfutures.edu.au
# computer-assist.co.uk
# softserv.co.in
# iclickmedia.com.sg
# bsmart.in
# techproject.com.au
# finesseglobal.in
# praemium.com.au
# stl.net.au
# stlgroup.co.uk
# unimedia.info
# coraltechnologies.co.in
# coraltechnologies.co.uk
# gensult.in
# osys.co.uk
# solnet.co.nz
# techinsight.io
# saharasystems.co.za
# amitel.eu
# prolinx.co.uk
# nanosoft.org.in
# getset.nu
# itsoft.in
# gsit.in
# netpeople.in
# teamit.co.za
# oakton.com.au
# oakton.edu
# sfera.eu
# adit.co.jp
# adit.ac.in
# trutech.ae
# race.ru
# netstudio.gr
# insystem.ru
# jilit.co.in
# cilix.co.mz
# go.com.mt
# tradesoft.ru
# zeta.in
# websys.co.in
# ctrl-shift.co.uk
# needltd.co.uk
# technosolution.co.in
# itsphere.co.in
# itsphere.co.uk
# citelecom.ci
# proact.eu
# tamdeed.ae
# digitalidea.co.kr
# footprint.co.za
# icreate.org.in
# iteam.co.uk
# additsolutions.gr
# cssp.co.uk
# ms-tech.co
# codesa.com.uy
# thebiggroup.com.au
# biggroup.co.uk
# thebiggroup.co
# inotech.co.uk
# idigital.cat
# idigital.co.il
# mercuryit.com.au
# infolog.com.sg
# 4tech.co.za
# digitalunion.com.au
# softwave.lk
# alpha.ae
# mbe.com.au
# bom.gov.au
# spcgroup.com.au
# ibee.in
# elevationmarketing.co.uk
# infodesign.ru
# infodesign.ro
# ico.com.hk
# itp.co.jp
# syscom.com.co
# newsjel.ly
# monochrome.co.uk
# irancell.ir
# ocs.ru
# codebox.com.sg
# autobar.nu
# analytics.pe
# snap.ie
# emtech.in
# livingmedia.com.au
# networkcommunication.co.nz
# auster.in
# techmind.co.in
# redwall.us
# redwall.com.tw
# parkerdesign.com.au
# itqan.ae
# agit.io
# setisa.com.sv
# c-tm.ru
# ----------
# altechisis.eu
# datacraft.com.au
# unicorn.eu
# asyst.co.za
# asyst.us
# enea.com.cn
# sdc.qld.edu.au
# sdc.co.uk
# inet.net.sa
# know-it.co.in
# gns.co.za
# gns.cri.nz
# itelco.tv
# scala.co.uk
# interact.org.uk
# altima.co.uk
# interact.ma
# interactltd.co.uk
# e-bit.io
# netsolutions.net.au
# rinf.ro
# rinf.tv
# matis.is
# apm.net.au
# apm.ru
# apm.org.uk
# apd.my
# apd.co.uk
# apdparcel.com.au
# apd.com.tw
# bsa.com.au
# telefonicamoviles.com.pe
# pitb.gov.pk
# c-b.co.uk
# tangible.co.th
# vass.vic.edu.au
# vass.co.uk
# king-ict.hr
# slt.lk
# rise-corp.tokyo
# tigerspike.jp
# dada.eu
# opensoft.com.pe
# avansys.edu.pe
# digitaldesign.co.uk
# onecom.co.uk
# icom.net.au
# comsats.net.pk
# mediabyte.net.au
# thinkinc.in
# thinkcompany.fi
# think.eu
# amcom.com.au
# unitedbusiness.co.za
# soltius.co.id
# soltius.co.nz
# primeur.co.uk
# mediasolutions.org.uk
# ekino.tv
# innovatefm.co.uk
# focus-solutions.co.uk
# tsolutions.co
# ct.co.uk
# ctco.lv
# desoft.cu
# matrix-global.com.cn
# matrixglobal.co.uk
# akros.ru
# bluefingroup.co.uk
# ergo.lt
# ergo.ee
# ergo.co.uk
# chorus.co.nz
# chorusgroup.co.uk
# aecgroup.co.in
# alma.ru
# eway.com.au
# profit.com.ve
# csoft.bg
# systematic.ru
# neosoft.hu
# neosoft.info
# computel.ru
# accel.com.au
# quid.ie
# cienet.com.cn
# keysystems.ru
# acceleration.ru
# stanleysecurity.eu
# multi-net.ru
# multinet.io
# bsb.in
# aist.go.jp
# aist.asn.au
# aist.net.ru
# dbi.ru
# wcs.edu
# sem.co.uk
# sia-group.com.cn
# sia-group.co.uk
# trans-it.ru
# gist.in
# gist.ac.kr
# smartnet.co.nz
# nexttechnologies.co.uk
# softec.sk
# helpline.co.uk
# tsoft.ru
# provision.com.au
# provisionltd.ie
# sysone.co.kr
# infosystem.co.in
# antevenio.co.uk
# technosoftsolutions.com.au
# technosoftsolutions.in
# humanit.com.au
# sbstechnologies.in
# firsttechnology.com.sg
# insoft.lt
# insoft.ru
# gmsservices.ru
# absolutesolutions.co.za
# absolute-solutions.co.uk
# bjit.co.jp
# codix.eu
# quadsel.in
# tdm.co.za
# mercator.ru
# mercator.com.au
# mercator.in
# sigma-it.ru
# alliance.co.nz
# turn-key.co
# babel.com.bd
# mediasoft.ru
# media-soft.info
# itsgroup.co.za
# prisma.fi
# cits.cn
# citsltd.co.uk
# cits.co.in
# esp.co.uk
# i-site.ph
# isite.co.in
# techmasters.io
# infoready.com.au
# personal.com.py
# addpeople.co.uk
# newcom.sg
# globalgroup.co.in
# herobusinesssolutions.eu
# strate.co.za
# itglobal.ru
# itglobal.com.au
# recro-net.hr
# neo.edu
# neocorp.co.in
# youco.eu
# youco.co.za
# exchangegroup.co.uk
# axen.pro
# sita.aero
# citc.gov.sa
# butterfly.co.jp
# financeit.io
# codehouse.com.au
# dennis.co.uk
# ip-label.co.uk
# tactica.in
# iptech.com.sg
# iptech.pro
# easysoftware.co.uk
# smartcom.co.za
# oxya.us
# biznet.co.jp
# csg.co.uk
# smartservicesltd.co.uk
# smartservices.net.in
# ipnet.ua
# ipnet.net.id
# innosys.co.za
# innosys.com.sg
# bonfire.com.au
# garena.co.id
# garena.ru
# sita.co.za
# agsgroup.com.hk
# telcom.ie
# stgroup.aero
# stgroup.co.za
# mistral.ru
# netcon.co.za
# vates.fi
# bootstrapcompany.co.uk
# emax.co.id
# astecmodels.co.uk
# infeurope.lu
# fornax.hu
# firsttech.co.za
# smartapps.com.au
# ----------
# byzan.com
# us2llc.com
# storagenetworks.com
# alphaonesolutions.com
# dykonpc.com
# pgtek.com
# adaquest.com
# aspheria.com
# you24h.com
# e-global.com.co
# keenicon.com
# tataelxsi.com
# techwisegroup.com
# encodeinc.com
# hallgroupsolutions.com
# valiantsolutions.com
# qtsdatacenters.com
# s2analyticalsolutions.com
# gallegasoft.com
# nexg.us
# divinesolutionscorp.com
# htcinc.com
# sysmaint.com
# telstraglobal.com
# ostglobal.com
# callcredit.co.uk
# allieddigital.net
# inteconusa.com
# praxis.co.za
# softserveinc.com
# systemsltd.com
# curatepartners.com
# jtsusa.com
# snapinc.net
# sr-professionals.com
# valuelabs.com
# ubtus.com
# xoriant.com
# 4s.net.sa
# 8networks.co.uk
# abcom.al
# acidgreen.com.au
# addictivemedia.co.in
# ajdservices.co.uk
# akcreation.co.uk
# algar.com.ph
# arabize.com.eg
# asset.com.eg
# avansys.in
# bcx.co.za
# bitech.com.sg
# bytemark.co.uk
# campaignmaster.co.uk
# cdcom.ru
# codeighteen.co.uk
# commtel.ae
# comsmart.co.nz
# consumercloudservices.co.uk
# crushdigital.co.uk
# cssp.com.au
# cyberspace.net.ng
# datacentrix.co.za
# datasys.co.uk
# datys.cu
# designamite.co.uk
# desysweb.pe
# digicert.com.my
# digitalbananas.co.uk
# digitalkeystone.co.uk
# digitalsense.com.au
# dinosys.vn
# dms.com.pe
# elgon.lu
# empathydesign.co.uk
# finxl.com.au
# foss.ae
# foxdigitalweb.com.au
# fusionunlimited.co.uk
# gbsi.com
# geonetsolutions.co.uk
# globalits.bh
# gss.com.tw
# iii.org.tw
# indigo-frog.co.uk
# intelligentgaming.co.uk
# intercom.com.eg
# ipsi.ie
# datanomics.com
# bravensinc.com
# businessintegra.com
# platinumesol.com
# dantatechnologies.net
# priserve.com
# noble1solutions.com
# adexus.com
# sparinfosys.com
# bakertilly.com
# adeptmax.com
# newtglobal.com
# kineticit.com.au
# 5280solutions.com
# redtoo.com
# biztech.com
# agile-defense.com
# hyperioninc.com
# megansoft.com
# triplei.com
# krishansh.com
# transquest.com
# lynxtp.com
# antra.net
# scintel.com
# standav.com
# mythics.com
# hadiamondstar.com
# cosapidata.com.pe
# eksource.com
# itbg.co.uk
# kcssolutions.co.uk
# knowit.co.uk
# landmarksystems.co.uk
# lateralsystems.com.au
# littlefish.co.uk
# llamadigital.co.uk
# lucidus.co.uk
# lumient.com.au
# machteamsoft.ro
# madmediagroup.com.au
# maint.com.ec
# mediabyte.com.pe
# medialounge.co.uk
# metadigital.co.uk
# mezzomedia.co.kr
# mindarc.com.au
# mit.com.mm
# mjf.ie
# mjflood.ie
# moraywebservices.co.uk
# mtn.sd
# muk.ua
# myitcentre.com.au
# neodreams.co.kr
# netcommunications.com.au
# networkit24.co.uk
# nvisage.co.uk
# orbe.co.cr
# originit.co.nz
# parker-design.co.uk
# peercore.com.au
# phaistosnetworks.gr
# pragma.com.co
# pral.com.pk
# pramerica.ie
# prosoft.com.eg
# prwd.co.uk
# radicaltechnologies.co.in
# rvtechnologies.co.in
# sevdotcom.ae
# shabakah.net.sa
# sicc.co.kr
# slickdesign.com.au
# smdigital.com.co
# soin.co.cr
# sol1.com.au
# solutionminds.com.au
# subisu.net.np
# syslogics.co.il
# teithe.gr
# thinknetworks.pe
# tsl-services.co.uk
# uplinx.com.au
# vbs.com.hk
# versegroup.com.au
# virtusystems.ru
# ward-analytics.co.uk
# webafrica.co.za
# woocom.com.au
# wtstechnologies.co.uk
# xronn.co.uk
# infosys.com
# systematix.co.uk
# itl.nnov.ru
# t-systems.sk
# drs.co.za
# fulcrum.co.uk
# internetsolutions.com.sa
# is.co.za
# omnitech.co.il
# valuepoint.co.in
# csd.co
# ncs.go.kr
# ncs.net.in
# eesllc.co
# dws.com.au
# novabase.eu
# softsolutions.co.in
# soft-solutions.co.za
# carat.co.za
# icl.net.au
# worldcall.com.pk
# ----------
# wonderwrks.com
# xoomworks.com
# 3sbc.com
# aboutweb.com
# alignstrategic.com
# analytics-me.com
# anteira.com
# aquanima.com
# arete-global.com
# axivas.com
# axsource.com
# az-consulenza.com
# baf-c.com
# beaconelectronics.com
# bglgroup.com
# bmwgroupdesignworks.com
# breilmann-ag.com
# btpeople.com.au
# campana-schott.com
# chakolas.com
# circularangle.com
# clavis.biz
# confiancegroup.com
# crowbell.com
# deevoirhr.com
# demandplanning.net
# dyemanagement.com
# effectus.co.nz
# erpi.net
# esentio.com
# expressworks.com
# flexymanagers.com
# futurecareersolutions.com
# gispgroup.com
# grupo2x.com
# icme.com
# iksap.com
# imrconsulting.com
# inconso.com
# incovis.com
# ishiftcorp.com
# integratedcomputerservices.com
# itsourcetek.com
# knowhowexperts.com
# koenandrews.com
# labtopiainc.com
# launch-hcm.com
# lightshippartners.com
# linxas.com
# navpoint.ca
# netatwork.com
# neumannpartners.com
# niplindia.com
# orbitak.com
# presenceofit.com
# q-perior.com
# quadrantix.com
# quintelmc.com
# qunie.com
# radford.com
# renoirgroup.com
# purple-vision.com
# avnet.com
# disrv.com
# spadetechnology.com
# brightstack.com
# lantanacom.com
# mtg-fl.com
# pm2net.com
# preferredtechnology.com
# yourtechteam.com
# operonsystems.com
# grovenetworks.com
# metistek.com
# nerdherd.com
# promedianj.com
# pylontechnology.com
# sisadmin.com
# datapartnerinc.com
# harbornetworks.com
# xtekpartners.com
# axnd.com
# computingmadesimple.org
# coretelligent.com
# gwtis.com
# invictuscommunications.com
# vertikal6.com
# asicllc.com
# cma-ideacom.com
# sanatechnology.com
# mindtree.com
# beinventiv.com
# birlasoft.com
# centricbiz.com
# cogecopeer1.com
# coresite.com
# cspi.com
# cvproject.us
# datalink.com
# datixinc.com
# dhigroupinc.com
# dkmrbh.com
# emergentsx.com
# eosintl.com
# eplus.com
# findly.com
# frugalbrothers.com
# highpoint-solutions.com
# hwcs.com
# identechnologies.com
# idexcel.com
# igate.com
# majesco.com
# meritsolutions.com
# microsourcing.com
# mstsolutions.com
# navisite.com
# netgainit.com
# neudesic.com
# newsignature.com
# novaturetech.com
# o2finfo.com
# odysseyis.com
# ontuitive.com
# optusinc.com
# packetfusion.com
# panduit.com
# peak10.com
# perficient.com
# pfsweb.com
# marlabs.com
# pisoftek.com
# piworldwide.com
# praxent.com
# preact.co.uk
# profad.com
# progilisys.com
# prosperoware.com
# provance.com
# radiansys.com
# rdacorp.com
# redflaggroup.com
# relation1.ca
# relus.com
# rhipesolutions.com
# sana-commerce.com
# sapiens.com
# saratechinc.com
# semanticspace.com
# sherweb.com
# sidetrade.com
# simba.com
# skykick.com
# smarthostdesign.com
# softlinegroup.com
# softwareag.com
# solidq.com
# solutions.canon.com
# solverusa.com
# sovos.com
# spigotsoft.com
# suyati.com
# swiftsystems.com
# tinesoftware.com
# tscti.com
# twbs.com
# udtonline.com
# virtusa.com
# westerncomputer.com
# xavor.com
# zero2ten.com
# nl.capgemini.com
# persistent.com
# zolontech.com
# variq.com
# srinav.net
# americansystems.com
# prolim.com
# infogain.com
# serti.com
# compupros.com
# nityo.com
# fishnetsecurity.com
# rsmus.com
# klouddata.com
# cohnreznick.com
# exceptionalsoftware.com
# insightnetworks.com
# coesyssolutions.com
# adaequare.com
# bartronics.com
# tekmasters.com
# techsophy.com
# citizant.com
# samsungsdsa.com
# netmagicsolutions.com
# orangepeople.com
# cegeka.com
# accela.com
# metrodata.co.id
# ----------
# vodavitech.com
# boldtechsolutions.com
# dutchsoft-technology.com
# eratis.co.za
# etechsco.com
# pbotech.com
# performance.gr
# soltechapps.com
# spro.com.cn
# sumraaztechnologies.com
# techiefolk.com
# umshini.com
# vagmine.com
# ambian.com.au
# crdsgroup.com
# flexprotechnology.com
# horizonplustechnologies.com
# kaykaytechnologies.com
# ma.com.au
# microincept.com
# ortecha.com
# rivantech.net
# riztechnologies.com
# suninfotechnology.com
# tandemtechnologiesllc.com
# techmatron.com
# technociates.com
# techprolite.com
# terratechnical.com
# twintechservices.com
# alltechnologynow.com
# amantechnology.com
# bmrtechnologies.com
# divulgetechnologies.com
# expotechinc.com
# idmaj.ma
# itechit.co.uk
# makkpress.com
# mitech1.com
# simontechway.com
# uvtechnocrats.com
# wiztech.net.in
# x3technology.com
# arveetechnologies.com
# firstpier.com
# ktstechnologies.com
# libyatech.ly
# mentortech.com.au
# mimitechnologies.com
# netplustechnologies.com
# nsi-africa.com
# ot-me.com
# phppixel.com
# s2technology.com
# trendztechnologies.com
# agastya.co.za
# aviop.com
# avisent-tech.com
# electtechnology.com
# eminencetechnology.com
# hsptechnologies.com
# id-mt.ru
# nfpaccounting.com
# pcmasterhightech.com
# profiletechnologies.com
# protechlosangeles.com
# qtsin.com
# smartxtechnologies.com
# sne.com.sg
# spinteg.com
# sumfive.com
# techassoc.com
# vandernet.biz
# xtremetechnolab.com
# amysoftech.in
# defineway.com
# ilotustechnologies.com
# in2end.com
# kvtechnologies.com
# latitudefintech.com
# lukoil-technology.com
# preville.us
# teamworkict.com
# technagroup.com
# technologysolutions.net
# techwaresystems.com
# uniprotek.com
# usage.com.my
# abraneo.com
# aerocom.net.au
# americantechnosys.com
# aquilatechnology.com
# arnatechnologies.com
# bigile.com
# brerptechnology.com
# datasettech.com
# flexisystech.com
# gmlnt.com
# intech-hawaii.com
# iqti.com
# leadtrance.com
# loremine.com
# omnivisiontechnology.com
# proteantech.com
# skynyx.in
# systechsoftwares.com
# techaccesspak.com
# techlions.co.uk
# technologydigest.net
# techspert-data.com
# thiatechnology.com
# treeshainfotech.com
# addon-tech.com
# allinfotech.com
# faithtechnologygroup.com
# intellium.co.nz
# mytechpro.com
# prenticetechnologies.com
# princetonreporting.com
# rkstech.com
# sdktec.com
# vlan.ca
# itcscorp.net
# rjtechnologies.com
# deebecon.com
# finitestates.com
# solve1.com
# zantek-it.com
# sysconscorp.com
# epsnetworks.com
# rmgcorp.com
# sapcle.com
# sierracorporation.com
# oasisky.com
# jigtechnologies.com
# justitsolution.com
# micro-datanet.com
# destech.com
# chrometechnologies.com
# firstapps.com
# synchronet.com
# ipnsinc.com
# slyontech.com
# emerion.ca
# awh.net
# oscits.com
# olsonsmith.com
# northshoretech.net
# cloverleafsolutions.com
# techsolgroup.ca
# sciente.com
# peaktsinc.com
# supretech.com
# wilcomsystems.com
# pexus.com
# seagrp.com
# sirc.net
# vantixsystems.com
# sharpsolutionsinc.com
# shepherdsearchgroup.com
# equinoxys.com
# expericon.fi
# line-of-sight.com
# logic2020.com
# naveltech.com
# oliverparks.com
# sequent.biz
# tridenttechnical.com
# abexsystems.com
# ac-elitepartners.com
# amarantocompany.com
# bluefusioninc.com
# ekuber.com
# enflexis.com
# expertum.net
# fdmgroup.com
# hcmnexus.com
# informaticconcepts.com
# innoplexus.com
# invenio-solutions.com
# legit-labs.com
# manifestlyimportant.com
# matisia.com
# navint.com
# noventum.eu
# oxleyenterprises.com
# pyvera.com
# resultspositive.com
# rukshaya.com
# scmt.com
# segalgroup.net
# seidor.com
# sesanv.com
# statminds.com
# sullivancotter.com
# tekbloomconsulting.com
# therainmakergroupinc.com
# titaniumcobra.com
# triumph-enterprises.com
# vcanss.com
# ----------
# www.poasystems.com
# www.powernetamerica.com
# www.redrockbusiness.com
# www.sierravistagroup.com
# www.softintl.com
# www.taaratech.com
# www.thcllc.com
# www.yesdi.com
# www.zantek-it.com
# xfinigent.com
# xlsoftek.com
# xutureit.com
# zilsol.com
# zdatainc.com
# malikco.com
# compucom.com
# stefanini.com
# techmahindra.com
# insasys.com
# rhyan.com
# biz4mation.com
# ci2iservices.com
# cloudsmartz.com
# cornelltechnical.com
# cvpcorp.com
# centillionz.com
# dyonyx.com
# gs5-llc.com
# iij.ad.jp
# jt3.com
# k2groupinc.com
# modussystems.com
# rdcbiz.com
# copperstoneconnect.com
# elevatets.com
# insequenceinc.com
# sagacy.com
# walkerhealthcareit.com
# ecsteam.com
# catapult.sc3.com
# charterglobal.com
# diversetech.com
# gmi.com
# tmrhq.com
# allegro.com
# aricent.com
# bitemarkgroup.com
# ecs-federal.com
# intech-inc.com
# mvsconsulting.com
# sc3.com
# yoofooz.techsitebuilder.com
# forsythe.com
# triumphtelecom.com
# arc-is.com
# gts-ts.com
# ikonotech.com
# corpbizsolutions.com
# cstltd.com
# everis.com
# syntelinc.com
# velocitycloud.com
# champsts.com
# abacustech.com
# tribridge.com
# tops-int.com
# milestonepowered.com
# telusinternational.com
# trigyn.com
# ciklum.com
# datamd.net
# ksmtechnologies.net
# mitresource.com
# netconnectglobal.com
# ritepros.com
# veritaaq.ca
# infopeoplecorp.com
# aforeserve.co.in
# computerware.in
# customertimes.com
# decisionmapper.com
# green.com.na
# jasperitinc.com
# keyintelligence.uk
# kpr.in
# lucidinfosystems.com
# netshellinfosystem.com
# wunderman.com
# zidnysolutions.com
# sqs.com
# astadia.com
# feuji.com
# crouchslavin.com
# smartsolutionsus.com
# indrasol.com
# syapps.com
# xavient.com
# universal-sw.com
# pundits.com
# exinent.com
# linium.com
# bourntec.com
# sellcraft.net
# icfi.com
# acentia.com
# meridiansoft.com
# vistronix.com
# solutionsiq.com
# geologics.com
# estuate.com
# compqsoft.com
# stiaos.com
# liquidhub.com
# irissoftware.com
# saviance.com
# mybridgepoint.com
# tcf.org.nz
# takesolutions.com
# zensar.com
# goeis.com
# gfi.world
# adpillc.com
# powersolv.com
# iknowvate.com
# taos.com
# healthplan.com
# teamcomputers.com
# damcogroup.com
# kaygen.com
# datatelinc.com
# edibasics.com
# reisystems.com
# nagarro.com
# dyntek.com
# msa.com
# hanzolabs.com
# silicus.com
# northpointcorp.com
# tellussol.com
# soais.com
# keyusa.com
# lantekcs.com
# accuvant.com
# columbusglobal.com
# jccs.com.sa
# softtek.com
# vacantum.com
# sts.com.jo
# csticorp.biz
# ness.com
# dimensiondata.com
# ust-global.com
# expinfo.com
# blackbox.com
# chenoainc.com
# concentrix.com
# teletech.com
# sonda.com
# tricoresolutions.com
# ncs.com.sg
# arkemtech.com
# broadrangetech.com
# corewebtechnology.com
# crd-tech.com
# dantatechnologies.com
# deas.in
# gosstech.com
# mannheimtech.com
# midwestindustrialtech.com
# oxfordliontech.com
# ricomtechnologies.com
# silvanotech.com
# systechservices.ca
# technogrity.com
# technos.co.uk
# techrakers.com
# utsi.us
# wati.com
# webghar.com
# bonkatechs.com
# dhyey.com
# extrememicrotech.com
# fairtechltd.com
# go-tag.net
# hisati.com
# hrt.bz
# incortech.com
# lakshmitechnologies.co.in
# naztechnologies.com
# pixelcare.com.sg
# pm4it.ca
# retetech.com
# s90.com
# skylarktechteam.com
# snoot.net
# talken.com
# tarvostechnologies.com
# techchoice.in
# v2softtech.com
# vidhaitech.com
# ----------
# sscs.com
# 3bridgesolutions.com
# adminservicesllc.com
# anaviatech.com
# anjitechnologies.com
# apextechllc.com
# applylogic.com
# approgence.com
# avithy.com
# axiom-systems.com
# bcmcgroup.com
# bdsninc.com
# beairdgroup.com
# bridge-services.com
# broadmoorsolutions.com
# bruckedwards.com
# cadmigos.com
# castortek.com
# cignussolutions.com
# claritypartners.com
# clockwork.ca
# condadogroup.com
# conzinitygroup.com
# crpsolutions.com
# cyberstreams.com
# cyclopeans.com
# dataredeemers.com
# datatechcafe.com
# decisionsource.com
# dintec.com
# dlfsystems.com
# dtm.ca
# econvergenceinc.com
# edrtechnology.com
# elajika.com
# eminenceinc.com
# ens-inc.com
# episervecorp.com
# eworldes.com
# excelonsolutions.com
# exertpoint.com
# exultancy.com
# flextech.com
# fpmtechnologies.com
# gaddeinc.com
# galaxux.com
# galvanassociates.com
# gestcom.ca
# gillaniconsulting.com
# gkbinc.biz
# globalintegratedtechnologysolutions.com
# globalintellectuals.com
# glocoms.com
# grandcubeinc.com
# hccoinc.com
# hchenterprisesllc.com
# healthinformaticsconsulting.ca
# heutechwelt.com
# hssolution.com
# hyperdatasystems.com
# hyrglobalsource.com
# hyteksw.com
# inavante.com
# infobeaninc.com
# infoplicity.com
# infusionpoints.com
# insystechinc.com
# intabyte.com
# intelligentsolutions.net
# intellizant.com
# iplannerinc.com
# istratsolutions.com
# itc2.net
# itcon-inc.com
# itobjects.com
# itvisionnc.com
# janatec.com
# jarsoft.com
# jarvantech.com
# jettbt.com
# jlmsystemsinc.com
# jsmninc.com
# kamyainc.com
# kassoftllc.com
# kensystemsinc.com
# kjtechnology.com
# kvstechnologies.com
# lodestonemc.com
# logistic-solutions.com
# lumensolns.com
# mahgosolutionsinc.com
# marisan.com
# mekonsoft.com
# migrationx.com
# mindrim.com
# nacopo.com
# nazdaqtechnologies.com
# netcloudtek.com
# netgurusystems.com
# netrus.com
# netup-it.com
# nexeon.biz
# nexstara.com
# nuvento.com
# obieeservices.com
# octatek.com
# oncorre.com
# orionventures.com
# otmlabs.com
# paktolus.com
# phanchor.com
# phigl.com
# phoenixendeavors.com
# pioneermultitech.com
# pmc-america.com
# predictivinsights.com
# pssincorporated.com
# purisolve.com
# pvramerica.com
# quadratics.com
# qualinfotech.com
# questam.com
# rayonsoft.com
# reliance-technologies.com
# ritnoa.com
# rmantras.com
# roansolutions.com
# rocontechnology.com
# rrgp.com
# rusdsolutions.com
# sankethinc.com
# saxonglobal.com
# scadea.net
# scubel.com
# shraytech.com
# siddhisystems.com
# sixred.com
# slkingtech.com
# smartstrategiesinc.com
# softnetus.com
# softwaretechnologylabs.com
# solutions4business.consulting
# srisoft-inc.com
# ssbsoftware.com
# ssgloballlc.com
# stgxinc.com
# strategint.com
# strativia.com
# sumpositive.com
# sunrayinformatics.com
# swiftsol.com
# synesisintl.com
# synaptikgroup.com
# synisys.com
# syntelligent.com
# syskii.com
# techheights.com
# techleapsystems.com
# technologyarc.com
# technoviz.com
# techteam.com
# tekerp.com
# tekleaders.com
# telematica.com
# terastone.com
# tggsinc.com
# thinkartha.com
# threebridge.com
# trinityww.com
# trivisioninc.com
# utisinc.com
# valuebasedprojectmanagement.net
# verbstech.com
# viewpoint-us.com
# vineva.com
# vishlent.com
# visoltech.com
# vsgbusinesssolutions.com
# webject.com
# www.actechnology.com
# www.apartechnologies.com
# www.atstechsolutions.com
# www.brandonsystems.com
# www.breakaway-inc.com
# www.bytecubed.com
# www.cep-inc.com
# www.ceragence.com
# www.confideit.com
# www.convisoinc.com
# www.datasensesolutions.com
# www.deferonet.com
# www.elegantsolutions.us
# www.fipsar.com
# www.gestcom.ca
# www.highernetworks.com
# www.indinus.com
# www.intellilinktech.com
# www.itsi-inc.com
# www.netsecurecorp.com
# www.oceanconsulting.com
# ----------
# url
# acriter-sa.com
# adduri.in
# allcommcr.com.pg
# altevie.com
# arkphire.com
# atea.lt
# binaria.com
# binaryglobal.com
# blueberrylabs.com
# bta.com
# calanit.com
# capasystems.com
# cloudtalent.co.uk
# codebibber.com
# coralhire.com
# credense.com
# daivahc.com
# daltron.com.pg
# divami.com
# divergencepeople.com
# ecritel.cn
# eitacies.com
# exclusive-networks.com
# exilesoft.com
# grupodigital.eu
# gruposolutio.com
# icctechnology.com
# intelshire.com
# itbmsindia.com
# itconic.com
# iteam.gr
# itna.co.za
# itqchile.com
# itqlatam.com
# itsoverlap.com
# itstk.com
# itway.com
# janeladigital.com
# lexel.co.nz
# metasite.net
# mtl.mw
# neelkanthinfonet.com
# netcb.com
# nextbridge.pk
# niletechnologies.com
# niyati.com
# oculusit.in
# pepkorit.com
# pitechplus.com
# prateektechnosoft.com
# priorityoneit.co.uk
# qualitance.com
# regal-it.com.au
# regenersis.in
# ropardo.ro
# sapphireims.com
# sapphiresystems.com
# sayers.com
# securitymatterz.com
# snsegypt.com
# softserve.ua
# solvinity.com
# stabilityit.com
# swifta.com
# symbia.com.pk
# systalent.com
# technocit.com
# tempest.sk
# unitebt.com
# vistarait.com
# voicegateindia.com
# whitehallsystems.com
# wittel.com
# xtensible.in
# xtravirt.com
# zealitech.com
# ativy.com
# dmss.co.in
# qual.co.uk
# resemblesystems.com
# saphiresolutions.com
# itblue.co.za
# newerait.co.nz
# drupaloutsourcing.com
# dynamicshires.com
# echelonservices.net
# hirevietnam.com
# locohire.com
# macprofessionals.com
# outsourzing.com
# computertalents.blogspot.com
# freightideas.com
# italentindia.com
# ittalent.com.co
# ittalents.com
# oratalents.com
# peopletalents.com
# talentamart.com
# talentedit.com
# talentelgia.com
# talenthat.in
# talentnet.com
# talentomobile.com
# talentsview.com
# talentway.fi
# vtalentglobal.com
# xomnia.com
# 3mindstrategic.com
# 4impact.com.au
# aitrg.com
# attra.com
# aviglo.com
# cahead.com
# capgemini.com
# ceiamerica.com
# cognizant.com
# compuga.com
# cquentsystems.com
# crestech.in
# effenti.ca
# emittance.net
# ensisinfo.com
# gbitinc.com
# ichipsolutions.com
# indusss.com
# innowix.com
# iotap.com
# keetechgroup.com
# korcomptenz.com
# nextstepinc.com
# nirasystems.com
# ondemandagility.com
# onyxmind.com
# otap-projects.com
# paraminfo.com
# petadigit.com
# pullskill.com
# raventure.com
# rigusinc.com
# sanrose.com
# servsolid.com
# silvercreeksoftware.com
# sovereigntec.com
# stansource.com
# swabzsystems.com
# swatsoftwarellc.com
# tantus.com
# teamwaresolutions.net
# teklysium.com
# themesoft.com
# trellistechsol.com
# vertexsolutionsinc.com
# wipro.com
# zusysinc.com
# sowre.com

# %% [markdown]
# # 3 Extract vislble text, clean text and store in csv file in final form for classifers

# %%
"""
This script extracts readable content from a set of raw html files.  It takes as input a file with tuples.
Each tuple is a filename which containing just one column of urls,
and the second element is simply a classification to tag all urls with.  
It's output will be a file similarly named, and will contain three columns...
url, visible_text, class

inputs:
    sets, Array of tupples. Each tuple is a filepath/class.  File contails urls to extract content from.
    html_content, Filepath to directory containing raw html files for extraction
output:
    file will be generated with 'data_for_classification' appended to source name.
return:
    None
"""
import os
print os.getcwd()

#INPUTS:
sets = [
     ("data/01_clean_url_lists/test.txt", 0),
     ("data/01_clean_url_lists/test_staff.txt", 1),
]
html_content = '../html_content'
target_path = 'data/02_training_sheets'
silent = False
# END INPUTS

import classification.data_extraction_functions as de
for fpath, binary in sets:
    de.disk_content_using_file_list(fpath, html_content, target_path, binary, silent=silent)
print "ALL DONE"
# Out:
# /Users/efrainolivares/repos/url_classifier_eoStaffingCleanup/notebooks
# Opening data/01_clean_url_lists/test.txt for urls
# Writing data to data/02_training_sheets/test_0.tsv
# 0
# Saved data to data/02_training_sheets/test_0.tsv
# Opening data/01_clean_url_lists/test_staff.txt for urls
# Writing data to data/02_training_sheets/test_staff_1.tsv
# 0
# url low content welcome to www.4.cn
# Saved data to data/02_training_sheets/test_staff_1.tsv
# ALL DONE

# %%
# !python -m pytest classification/data_extraction_functions.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 2.7.10, pytest-3.1.3, py-1.4.34, pluggy-0.4.0 -- /Users/efrainolivares/envnltk/bin/python
# cachedir: .cache
# rootdir: /Users/efrainolivares/repos/url_classifier_eoStaffingCleanup/notebooks, inifile:
# collected 6 items
#
# classification/data_extraction_functions.py::test_lowercase PASSED
# classification/data_extraction_functions.py::test_paragraph PASSED
# classification/data_extraction_functions.py::test_script PASSED
# classification/data_extraction_functions.py::test_style PASSED
# classification/data_extraction_functions.py::test_style2 PASSED
# classification/data_extraction_functions.py::test_clean_out_junk_words PASSED
#
# =========================== 6 passed in 0.07 seconds ===========================
