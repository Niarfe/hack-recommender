# %% [markdown]
# # Sentiment analysis on Trump's tweets using Python
#
# Original [link](https://dev.to/rodolfoferro/sentiment-analysis-on-trumpss-tweets-using-python-)

# %%
# !which python
import os
print os.getcwd()
#!pip install tweepy
import tweepy
import pandas as pd
import numpy as np

# For plotting and visualization
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/niarfe/envscikit/bin/python
# /Volumes/Transcend/repos/eo-hg-sandbox/blogs/blog-extracting-sentiment-trumps-tweets
# /Users/niarfe/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
with open('credentials.py', 'w') as target:
    # You actually have to put in your keys here from your twitter account
    # https://apps.twitter.com/app/14244960/keys
    # that is for saguarotrump app, with user EfrainOlivares1
    target.write("CONSUMER_KEY    = '{}'\n".format("-consumer key-"))
    target.write("CONSUMER_SECRET    = '{}'\n".format("-consumer secret-"))
    target.write("ACCESS_TOKEN = '{}'\n".format("-access token-"))
    target.write("ACCESS_SECRET = '{}'\n".format("-access secret-"))
    
# !ls | grep credentials.py; wc -l credentials.py
# !cat credentials.py
# Out:
# credentials.py
# credentials.pyc
#        4 credentials.py
# CONSUMER_KEY    = '-consumer key-'
# CONSUMER_SECRET    = '-consumer secret-'
# ACCESS_TOKEN = '-access token-'
# ACCESS_SECRET = '-access secret-'

# %%
from credentials import *
print CONSUMER_KEY

def twitter_setup(CONSUMER_IEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_SECRET):
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    
    api = tweepy.API(auth)
    return api
# Out:
# PQnkHibyQGDSFlv4Q7pIgUrR4

# %%
extractor = twitter_setup(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_SECRET)

tweets = extractor.user_timeline(screen_name="realDonaldTrump", count=200)
print ("Number of tweets extracted: {}.\n".format(len(tweets)))

print ("5 recent tweets:\n")
for tweet in tweets[:5]:
    print (tweet.text)
    print()
# Out:
# Number of tweets extracted: 200.
#
# 5 recent tweets:
#
# I will be in Huntsville, Alabama, on Saturday night to support Luther Strange for Senate. "Big Luther" is a great guy who gets things done!
# ()
# Attorney General Bill Shuette will be a fantastic Governor for the great State of Michigan. I am bringing back your jobs and Bill will help!
# ()
# A great deal of good things happening for our country. Jobs and Stock Market at all time highs, and I believe will be getting even better!
# ()
# HAPPY 70th BIRTHDAY to the @USAirForce! The American people are eternally grateful. Thank you for keeping America P… https://t.co/AwuBR6TA9C
# ()
# We will defend our people, our nations and our civilization from all who dare to threaten our way of life...cont:… https://t.co/LMkSj1vzOI
# ()

# %%
# use pandas to view the data
# We create a pandas dataframe as follow:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe
display(data.head(10))
# Out:
#                                               Tweets
# 0  I will be in Huntsville, Alabama, on Saturday ...
# 1  Attorney General Bill Shuette will be a fantas...
# 2  A great deal of good things happening for our ...
# 3  HAPPY 70th BIRTHDAY to the @USAirForce! The Am...
# 4  We will defend our people, our nations and our...
# 5  Our hearts &amp; prayers go out to the people ...
# 6  NEVER forget our HEROES held prisoner or who h...
# 7  Frank “FX” Giaccio-\nOn behalf of @FLOTUS Mela...
# 8         WEEKLY ADDRESS🇺🇸 https://t.co/MsaLA9POAt
# 9  CHAIN MIGRATION cannot be allowed to be part o...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__doc__', '__eq__', '__format__', '__getattribute__', '__getstate__', '__hash__', '__init__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 909191177810915328
# 2017-09-16 23:04:03
# Twitter for iPhone
# 33230
# 6559
# None
# None
# {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': []}

# %%
# We add relevant data:
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets  len                  ID  \
# 0  I will be in Huntsville, Alabama, on Saturday ...  139  909191177810915328
# 1  Attorney General Bill Shuette will be a fantas...  140  909189931154771970
# 2  A great deal of good things happening for our ...  138  909185223887347712
# 3  HAPPY 70th BIRTHDAY to the @USAirForce! The Am...  140  908841360131743744
# 4  We will defend our people, our nations and our...  138  908827394856947712
# 5  Our hearts &amp; prayers go out to the people ...  124  908796281002307584
# 6  NEVER forget our HEROES held prisoner or who h...  140  908768057140629506
# 7  Frank “FX” Giaccio-\nOn behalf of @FLOTUS Mela...  133  908734537311678464
# 8         WEEKLY ADDRESS🇺🇸 https://t.co/MsaLA9POAt   42  908724382440284160
# 9  CHAIN MIGRATION cannot be allowed to be part o...   79  908676979561570304
#
#                  Date              Source   Likes    RTs
# ...

# %%
# We extract the mean of lengths:
mean = np.mean(data['len'])

print("The length's average in tweets: {}".format(mean))
# Out:
# The length's average in tweets: 127.235

# %%
# We extract the tween with more FAVs and more RTs:
fav_max = np.max(data['Likes'])
rt_max = np.max(data['RTs'])
fav = data[data.Likes == fav_max].index[0]
rt  = data[data.RTs == rt_max].index[0]

# Max FAVs:
print("The tweet with more likes is: \n{}".format(data['Tweets'][fav]))
print("Number of likes: {}".format(fav_max))
print("{} characters.\n".format(data['len'][fav]))

# Max RTs:
print("The tweet with more retweets is: \n{}".format(data['Tweets'][rt]))
print("Number of retweets: {}".format(rt_max))
print("{} characters.\n".format(data['len'][rt]))
# Out:
# The tweet with more likes is:
# The United States is considering, in addition to other options, stopping all trade with any country doing business with North Korea.
# Number of likes: 171715
# 132 characters.
#
# The tweet with more retweets is:
# The United States is considering, in addition to other options, stopping all trade with any country doing business with North Korea.
# Number of retweets: 46854
# 132 characters.

# %%
# We create time series for data:

tlen = pd.Series(data=data['len'].values, index=data['Date'])
tfav = pd.Series(data=data['Likes'].values, index=data['Date'])
tret = pd.Series(data=data['RTs'].values, index=data['Date'])

# Lenghts along time:
tlen.plot(figsize=(16,4), color='r');

# %%
# Likes vs retweets visualization:
tfav.plot(figsize=(16,4), label="Likes", legend=True)
tret.plot(figsize=(16,4), label="Retweets", legend=True);

# %%
# We obtain all possible sources:
sources = []
for source in data['Source']:
    if source not in sources:
        sources.append(source)

# We print sources list:
print("Creation of content sources:")
for source in sources:
    print("* {}".format(source))
# Out:
# Creation of content sources:
# * Twitter for iPhone
# * Media Studio

# %%
# We create a numpy vector mapped to labels:
percent = np.zeros(len(sources))

for source in data['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

percent /= 100

# Pie chart:
pie_chart = pd.Series(percent, index=sources, name='Sources')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6));

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
# We create a column with the result of the analysis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# We display the updated dataframe with the new column:
display(data.head(10))
# Out:
#                                               Tweets  len                  ID  \
# 0  I will be in Huntsville, Alabama, on Saturday ...  139  909191177810915328
# 1  Attorney General Bill Shuette will be a fantas...  140  909189931154771970
# 2  A great deal of good things happening for our ...  138  909185223887347712
# 3  HAPPY 70th BIRTHDAY to the @USAirForce! The Am...  140  908841360131743744
# 4  We will defend our people, our nations and our...  138  908827394856947712
# 5  Our hearts &amp; prayers go out to the people ...  124  908796281002307584
# 6  NEVER forget our HEROES held prisoner or who h...  140  908768057140629506
# 7  Frank “FX” Giaccio-\nOn behalf of @FLOTUS Mela...  133  908734537311678464
# 8         WEEKLY ADDRESS🇺🇸 https://t.co/MsaLA9POAt   42  908724382440284160
# 9  CHAIN MIGRATION cannot be allowed to be part o...   79  908676979561570304
#
#                  Date              Source   Likes    RTs  SA
# ...

# %%
# We construct lists with classified tweets:

pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# We print percentages:

print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Percentage of positive tweets: 51%
# Percentage of neutral tweets: 29%
# Percentage de negative tweets: 19%
