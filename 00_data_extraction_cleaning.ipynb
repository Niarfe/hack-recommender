# %% [markdown]
# # Process for cleaning url lists from SQL database
#
# The url lists for classification of staffing and IT-Consultants start out as queries from pocitac database.
# The format is usually a multi column csv file from which we are interested in the url column.
# The files are usually associated with a particular classification, for example manual-classified-staffing.
# This sequence of steps takes files from raw sql dumps and outputs at the end csv tables with three columns.
#
#
# | url       | content         | class |
# |-----------|-----------------|-------|
# | acme.com  | we are staffing |   0   |
#
#
# These output files in turn are used by scikit learn to train the models.
# The model itself is saved to disk and used by the EMR job during the url-classification runs monthly.

# %%
"""
Extract data from csv files which are provided from the SQL database.

File Input format is 
id,url,reason,origin,dbl_verified,product_hits,added_at
1,acriter-sa.com,tech_consult,manual_jodi,NULL,0,2016-09-09
2,adduri.in,tech_consult,manual_jodi,NULL,0,2016-09-09

File Output format is a txt file with a single column one url per line


inputs:
    source_name, Filename/path of file containing raw url lists from database.
    output_name, Filename to use for file which will contain only the urls
return:
    None
"""
source_name = 'url_lists/tech_consult_manual_suppress_on_url.csv'
output_name = 'url_lists/tech_consult_manual_urls.txt'


import pandas as pd

print "Reading input file and extracting the url vertical to save to file"
df = pd.read_csv(source_name)
df[['url']].to_csv(output_name, index=False) # index=False keeps it from writing out the row number...

print "Printing out the first rows of the output file for verification"
df_out = pd.read_csv(output_name)
df_out.head()

print "ALL DONE"
df_out.head()
# Out:
# Reading input file and extracting the url vertical to save to file
# Printing out the first rows of the output file for verification
# ALL DONE
#                     url
# 0        acriter-sa.com
# 1             adduri.in
# 2     advancedit.com.br
# 3  aequitas-affinity.de
# 4      allcommcr.com.pg

# %% [markdown]
# # Manual Step: Run the output list from previous cell through the url-classifier in text saving mode.
#
# ## Steps
# 1. At command line, set paths for saving text file by editing set_flag/save_file_on and set folder path.
# 1. Set the flag now by executing `. set_flag/save_file_on`
# 1. Now run the source file with `cat <source file> | python bin/urlChecker.py`
# 1. All the urls in the file should have a corresponding file saved in the output folder set.

# %%
"""
This script extracts readable content from a set of raw html files.  It takes as input a file with tuples.
Each tuple is a filename, containing just one column of urls, and it's classification.  
It's output will be a file similarly named, and will contain three columns...
url, visible_text, class

inputs:
    sets, Array of tupples. Each tuple is a filepath/class.  File contails urls to extract content from.
    html_content, Filepath to directory containing raw html files for extraction
output:
    file will be generated with 'data_for_classification' appended to source name.
return:
    None
"""

#INPUTS:
sets = [
     ("url_lists/tech_consult_manual_urls.txt", 0)
#     ("url_lists/test.txt", 0)
]
html_content = 'html_content_tech_consult'


from bs4 import BeautifulSoup
from bs4 import Comment
from bs4 import CData
import os
import re
import lxml
import bin.get_visible_text as gt


def disk_content_using_file_list(flist, source_path, binary):
    """Create a csv file with url, content, binary per row from given list of urls and content on disk
        flist: path of file to parse for names.
        source_path: directory with html content, where file names are same as url
        binary: what category should these be considered, 0/1
    """
    with open(flist, 'r') as source, open("data_for_classification_{}.tsv".format(str(binary)),'w') as target:
        for line in source:
            path_file = "{}/{}".format(source_path, line.strip())
            if os.path.exists(path_file):
                with open("{}/{}".format(source_path, line.strip()), 'r') as html_source:
                    html_text = html_source.read().decode('ascii', 'ignore')
                    visible_text = gt.get_visible_text(html_text)
                    if len(visible_text) >= 20:
                        target.write("{}\t{}\t{}\n".format(
                            line.strip(),
                            visible_text.encode('ascii','ignore'),
                            binary
                        ))
                    else:
                        print "{} low content {}".format(line.strip(), visible_text.encode('ascii', 'ignore'))
            else:
                print "{} not found".format(path_file)




for fpath, binary in sets:
    disk_content_using_file_list(fpath, html_content, binary)
print "ALL DONE"
# Out:
# html_content_tech_consult/url not found
# capasystems.com low content
# html_content_tech_consult/daltron.com.pg not found
# html_content_tech_consult/neelkanthinfonet.com not found
# stabilityit.com low content
# winprovit.pt low content  winprovit
# locohire.com low content
# html_content_tech_consult/outsourzing.com not found
# html_content_tech_consult/peopletalents.com not found
# html_content_tech_consult/cadmigos.com not found
# inavante.com low content
# html_content_tech_consult/intabyte.com not found
# html_content_tech_consult/janatec.com not found
# html_content_tech_consult/mekonsoft.com not found
# html_content_tech_consult/nexstara.com not found
# html_content_tech_consult/obieeservices.com not found
# html_content_tech_consult/qualinfotech.com not found
# html_content_tech_consult/softwaretechnologylabs.com not found
# stgxinc.com low content
# synaptikgroup.com low content
# html_content_tech_consult/tekerp.com not found
# html_content_tech_consult/vineva.com not found
# www.atstechsolutions.com low content
# html_content_tech_consult/www.deferonet.com not found
# html_content_tech_consult/www.netsecurecorp.com not found
# html_content_tech_consult/www.oceanconsulting.com not found
# html_content_tech_consult/www.poasystems.com not found
# html_content_tech_consult/www.softintl.com not found
# sc3.com low content
# html_content_tech_consult/triumphtelecom.com not found
# compqsoft.com low content
# arkemtech.com low content  arkemtech
# html_content_tech_consult/systechservices.ca not found
# html_content_tech_consult/technogrity.com not found
# html_content_tech_consult/lakshmitechnologies.co.in not found
# html_content_tech_consult/techchoice.in not found
# html_content_tech_consult/riztechnologies.com not found
# sytech.com.br low content  sytech
# technociates.com low content  technociates.com
# html_content_tech_consult/uvtechnocrats.com not found
# html_content_tech_consult/xtremetechnolab.com not found
# usage.com.my low content
# html_content_tech_consult/proteantech.com not found
# html_content_tech_consult/leaftech.com.mx not found
# html_content_tech_consult/princetonreporting.com not found
# html_content_tech_consult/deevoirhr.com not found
# launch-hcm.com low content
# html_content_tech_consult/sanatechnology.com not found
# html_content_tech_consult/rhipesolutions.com not found
# html_content_tech_consult/riplife.es not found
# orangepeople.com low content  orangepeople
# html_content_tech_consult/us2llc.com not found
# html_content_tech_consult/divinesolutionscorp.com not found
# allieddigital.net low content
# anyware.be low content
# html_content_tech_consult/aroma-services.com.tn not found
# html_content_tech_consult/bizqit.nl not found
# fluxit.com.ar low content
# inmotion.cl low content  in motion
# itpartner.no low content
# mainline.it low content  mainline s.r.l.
# neodreams.co.kr low content
# html_content_tech_consult/netcommunications.com.au not found
# html_content_tech_consult/nice2do.nl not found
# html_content_tech_consult/pro-marketing.be not found
# html_content_tech_consult/sevdotcom.ae not found
# smdigital.com.co low content
# html_content_tech_consult/gtt.to.it not found
# html_content_tech_consult/internetsolutions.com.sa not found
# qualitest.com.br low content  qualitest
# ncs.go.kr low content
# html_content_tech_consult/wavegroup.it not found
# eesllc.co low content
# html_content_tech_consult/carat.co.za not found
# html_content_tech_consult/datacraft.com.au not found
# unicorn.eu low content  unicorn
# interactivegroup.se low content  iabc
# parc.com.mx low content  parc.com.mx
# e-bit.io low content
# html_content_tech_consult/e-bit.com.tr not found
# html_content_tech_consult/rinf.tv not found
# apd.my low content  apd
# html_content_tech_consult/bsa.com.au not found
# telefonicamoviles.com.pe low content  mi movistar
# html_content_tech_consult/tangible.co.th not found
# avansys.com.mx low content
# html_content_tech_consult/mediabyte.net.au not found
# html_content_tech_consult/thinkinc.in not found
# html_content_tech_consult/innovate.com.mx not found
# html_content_tech_consult/niscayah.fr not found
# html_content_tech_consult/bsb.in not found
# sysone.co.kr low content  ::: sysone :::
# quadsel.in low content  quadsel system
# itlab.com.br low content
# altecsa.com.mx low content  altecsa
# html_content_tech_consult/prisma.fi not found
# newcom.sg low content  newcom
# html_content_tech_consult/agileit.fr not found
# axen.pro low content
# html_content_tech_consult/iptech.pro not found
# techdata.cz low content  mp
# biznet.co.jp low content  ec ec /
# html_content_tech_consult/ipnet.net.id not found
# html_content_tech_consult/garena.ru not found
# html_content_tech_consult/sita.co.za not found
# e-max.be low content
# r-tech.co.in low content
# html_content_tech_consult/hrboss.co.jp not found
# everett.eu low content
# html_content_tech_consult/vizadanetworks.co.tz not found
# html_content_tech_consult/logicom.com.br not found
# html_content_tech_consult/advanced-software.de not found
# html_content_tech_consult/hsbcglt.com.br not found
# html_content_tech_consult/csbi.waw.pl not found
# optimizer.pt low content  optimizer
# html_content_tech_consult/mastercom.net.br not found
# html_content_tech_consult/medialounge.in not found
# html_content_tech_consult/reliableservices.net.in not found
# future.it low content  future.it
# html_content_tech_consult/appsource.co.in not found
# html_content_tech_consult/infocenter.com.py not found
# infocenter.com.br low content  infocenter
# html_content_tech_consult/softserv.co.in not found
# html_content_tech_consult/saharasystems.co.za not found
# sysdata.nl low content  homepage
# html_content_tech_consult/gsit.fr not found
# html_content_tech_consult/go.com.mt not found
# tradesoft.com.br low content  tradesoft
# orden.cl low content  orden index
# axones.com.ar low content
# html_content_tech_consult/itpower.com.br not found
# idigital.cat low content
# spcgroup.com.au low content  underconstruction
# info-design.fr low content  info-design
# html_content_tech_consult/livingmedia.com.au not found
# html_content_tech_consult/creativeteam.com.mx not found
# html_content_tech_consult/itsas.us not found
# html_content_tech_consult/proactive-partners.ch not found
# abctechnology.co.uk low content
# pluscommunication.pl low content  plus
# html_content_tech_consult/gentel.com.tr not found
# html_content_tech_consult/kcs.com.kw not found
# html_content_tech_consult/perspektiv.co.uk not found
# easycom.it low content  easycom
# html_content_tech_consult/easycom.co not found
# iron-web.co.uk low content
# html_content_tech_consult/msdevelop.com.br not found
# onoff.fr low content
# media-line.it low content
# reverside.co.za low content  reverside
# codit.com.br low content  codit
# rootmedia.mobi low content  rootmedia.mobi
# walkerscott.co low content
# html_content_tech_consult/itcommerce.com.br not found
# html_content_tech_consult/dtdigital.co.uk not found
# isbel.com.uy low content  isbel
# html_content_tech_consult/lincom.net.au not found
# html_content_tech_consult/protean.com.mx not found
# html_content_tech_consult/secureservices.bh not found
# ingecon.com.br low content  ingecon
# html_content_tech_consult/evagroup.com.au not found
# html_content_tech_consult/creacom.com.au not found
# pro-bit.si low content
# rsn.com.co low content
# html_content_tech_consult/tistech.co.ao not found
# spaziozerouno.it low content
# html_content_tech_consult/isat.com.mx not found
# html_content_tech_consult/linktechsolutions.com.au not found
# html_content_tech_consult/yaptechnology.pt not found
# html_content_tech_consult/thecreativefactory.ch not found
# html_content_tech_consult/izonesolutions.in not found
# certinergy.co.uk low content  site offline
# html_content_tech_consult/activeoffice.se not found
# html_content_tech_consult/sielco.it not found
# html_content_tech_consult/globalbesttech.com.mx not found
# html_content_tech_consult/onlineservices.no not found
# html_content_tech_consult/goshawkaerospace.co.uk not found
# simplexsolution.de low content  ber mich
# html_content_tech_consult/lispa.it not found
# html_content_tech_consult/pitrez.com.br not found
# yourideas.org.uk low content  yourideasredditch
# html_content_tech_consult/techcommerce.co.il not found
# bhambi.com low content
# kbscorp.com low content  kbscorp
# html_content_tech_consult/sav-on-software.com not found
# techcomsolutions.net low content
# html_content_tech_consult/atgcorp.com not found
# html_content_tech_consult/incedo.de not found
# html_content_tech_consult/pentalog.com not found
# html_content_tech_consult/pentalog.fr not found
# html_content_tech_consult/vangent.com not found
# html_content_tech_consult/winwire.com not found
# html_content_tech_consult/timberhorn.com not found
# dewsoftware.com low content  shares
# html_content_tech_consult/3ktechnologies.com not found
# html_content_tech_consult/systemguru.com not found
# html_content_tech_consult/technology-solution.com not found
# infinitisystems.com low content
# html_content_tech_consult/dice.co.uk not found
# infowarets.com low content
# protechnicals.com low content
# html_content_tech_consult/dataexel.com not found
# cannonsp.com low content  cannonsp.com
# html_content_tech_consult/hp.taleo.net not found
# html_content_tech_consult/gtcsystems.com not found
# f1techsolutions.com low content
# html_content_tech_consult/sohosquaresolutions.com not found
# html_content_tech_consult/sigmanet.com not found
# html_content_tech_consult/dextrys.com not found
# intigrow.com low content
# html_content_tech_consult/bluewave-computing.com not found
# masterpeaceltd.com low content  masterpeace
# html_content_tech_consult/safebridgeinc.com not found
# ucomusa.com low content
# ericrobert.com low content
# bridgelinx.com low content
# html_content_tech_consult/zeno-inc.com not found
# html_content_tech_consult/kellerschroeder.com not found
# crescendollc.com low content
# html_content_tech_consult/ctiteksource.com not found
# html_content_tech_consult/predicainc.com not found
# capcomputer.com low content  capital computer
# dfwtechnology.com low content  dfw technology
# param-solutions.com low content  param solutions
# html_content_tech_consult/tekmate.net not found
# html_content_tech_consult/techcessgroup.com not found
# html_content_tech_consult/golime.co not found
# html_content_tech_consult/bypronto.com not found
# advanced-networks.com low content  advanced-networks
# atstechsolutions.com low content
# html_content_tech_consult/numanetworks.com not found
# html_content_tech_consult/isworks.com not found
# html_content_tech_consult/appirio.com not found
# html_content_tech_consult/dmsinc.com not found
# html_content_tech_consult/bitsltd.net not found
# html_content_tech_consult/frontier.in not found
# html_content_tech_consult/bluesoft.net.pl not found
# html_content_tech_consult/bluesoft.co.uk not found
# html_content_tech_consult/bluesoft-group.com not found
# html_content_tech_consult/true.nl not found
# html_content_tech_consult/isban.com not found
# html_content_tech_consult/isban.es not found
# html_content_tech_consult/isban.com.br not found
# html_content_tech_consult/barrister.com not found
# html_content_tech_consult/tecnocom.com.br not found
# html_content_tech_consult/tekcomms.com not found
# html_content_tech_consult/itcs-group.com not found
# html_content_tech_consult/claranet.com not found
# html_content_tech_consult/coreservices.com not found
# html_content_tech_consult/eesllc.net not found
# html_content_tech_consult/exis-ti.com not found
# html_content_tech_consult/oberon.eu not found
# html_content_tech_consult/pythian.com not found
# html_content_tech_consult/seltd.com not found
# html_content_tech_consult/business.com not found
# html_content_tech_consult/ctp.com not found
# html_content_tech_consult/bsscorp.com not found
# icmcorporation.com low content  icmtechgroup
# html_content_tech_consult/lnttechnologyservices.com not found
# html_content_tech_consult/lttechnologyservices.com not found
# html_content_tech_consult/ctis.de not found
# html_content_tech_consult/ctis.com.mx not found
# html_content_tech_consult/ctisinc.com not found
# html_content_tech_consult/groupeonepoint.com not found
# html_content_tech_consult/techsolutions.net not found
# html_content_tech_consult/techsolutionsinc.com not found
# html_content_tech_consult/techsolutions.com not found
# html_content_tech_consult/techsolutionsllc.com not found
# html_content_tech_consult/synapse.com not found
# html_content_tech_consult/synapsellc.com not found
# html_content_tech_consult/man.com not found
# html_content_tech_consult/incedoinc.com not found
# html_content_tech_consult/computersolutions.ca not found
# html_content_tech_consult/computersolutions.ie not found
# html_content_tech_consult/futureplc.com not found
# html_content_tech_consult/caprusit.com not found
# html_content_tech_consult/dialog.com.au not found
# html_content_tech_consult/ains.com.au not found
# html_content_tech_consult/taldor.co.il not found
# html_content_tech_consult/link.pt not found
# html_content_tech_consult/galaxe.com not found
# html_content_tech_consult/ntt.com not found
# html_content_tech_consult/innovainc.com not found
# html_content_tech_consult/telindus.nl not found
# html_content_tech_consult/interface.ru not found
# html_content_tech_consult/edgets.com not found
# html_content_tech_consult/itgct.com not found
# html_content_tech_consult/georgiait.com not found
# mts-usa.com low content
# html_content_tech_consult/data3.com not found
# html_content_tech_consult/grupo-sms.com not found
# html_content_tech_consult/issupppressstechnologies.com not found
# html_content_tech_consult/ssupppressstematix.com not found
# html_content_tech_consult/ssupppressnchronissupppresss.com not found
# html_content_tech_consult/criterion-ssupppresss.com not found
# html_content_tech_consult/bluecanopsupppress.com not found
# html_content_tech_consult/analsupppresstica.net not found
# html_content_tech_consult/terpssupppresss.com not found
# ppc.com low content  ppc-llc
# html_content_tech_consult/entelgy.com.br not found
# nidhusoft.com low content
# internalcomputerservices.com low content  intcomser
# crystalclearcomputersolutions.com low content
# concretesolutions.com.br low content  concrete
# html_content_tech_consult/insags.com not found
# bematech.com.br low content
# html_content_tech_consult/checkmarx.com not found
# infomedika.com low content  infomedika
# ALL DONE
